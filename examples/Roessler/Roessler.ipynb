# %% [markdown]
# <a href="https://colab.research.google.com/github/ContiPaolo/Complete-Python-3-Bootcamp/blob/master/examples/Roessler/Roessler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Perform all necessary imports

# %%
###########################  CLONE VENI-VINDy-VICI AND INSTALL VINDy PACKAGE  ###########################
from IPython.display import clear_output
import sys
sys.path.append('/content/VENI-VINDy-VICI')
print("Clone VENI-VINDy-VICI repository and install VINDy package")
# !git clone https://github.com/jkneifl/VENI-VINDy-VICI
# !pip install vindy
clear_output()
print("VENI-VINDy-VICI ready to go :)")
# Out:
# VENI-VINDy-VICI ready to go :)

# %%
import tensorflow as tf
import os
import numpy as np
from vindy import SindyNetwork
from vindy.libraries import PolynomialLibrary
from vindy.layers import SindyLayer, VindyLayer
from vindy.distributions import Gaussian, Laplace
from vindy.callbacks import (
    SaveCoefficientsCallback,
)
sys.path.append('/content/VENI-VINDy-VICI/examples/Roessler')
from Roessler_utils import data_generation, generate_directories, data_plot, training_plot, trajectory_plot, uq_plot

# %% [markdown]
# ## Roessler System
# The Roessler system is a system of three ordinary differential equations that describe a simple chaotic system. The equations are given by:
# $ \dot{z}_1 = -z_2 - z_3 $
# $ \dot{z}_2 = z_1 + 0.2*z_2 $
# $ \dot{z}_3 = 0.2 + z_3(z_1-5.7) = 0.2 + z_3 z_1 - 5.7z_3 $

# %%
def roessler(t, x0, a=0.2, b=0.2, c=5.7):
    x, y, z = x0
    return [-y - z, x + a * y, b + z * (x - c)]

# %% [markdown]
# Let's define some general script parameters including the noise factors, the number of training and test trajectories, and the random seed. We will also define the type of SINDy model we want to use (VINDy or SINDy) and the model name (Roessler or LV). With the following setup we train our system on data with measurement noise and model noise. We will also use random initial conditions and parameters for the Roessler system.

# %%
sindy_type = "vindy"  # "sindy" or "vindy"
model_name = "roessler"  # LV or roessler
seed = 29 # random seed
random_IC = True # use random initial conditions
random_a = True # use random parameters (a in the Roessler system)
measurement_noise_factor = 0.01 # measurement noise factor
model_noise_factor = 0.1 # model noise factor
n_train = 30 # number of training trajectories
n_test = 4 # number of test trajectories

# %% [markdown]
# Let's define directories for saving the results

# %%
# noise before derivative, model error, seed
scenario_info = f"{sindy_type}_nbd__me_{random_a}_{model_noise_factor}_seed_{seed}_noise_{measurement_noise_factor}"
_, _, _, weights_dir = generate_directories(model_name, sindy_type, scenario_info, "results")

# %% [markdown]
# First, we will generate the data for the Roessler system that we can use to train the VINDy model. We will use the `scipy.integrate.solve_ivp` function to solve the ODEs and generate the data. Let's plot the data to see what it looks like

# %%
(
    t,
    x,
    dxdt,
    x_test,
    dxdt_test,
    var_names,
    dim
) = data_generation(roessler, n_train, n_test, random_IC, random_a, seed, model_noise_factor, measurement_noise_factor)

data_plot(t, x, dxdt, x_test)

# %% [markdown]
# ## Model Generation
#
# Now, we will define the VINDy model and train it on the generated data to learn the Roessler system. We will use the `VariationalSindyLayer` to define the model. The `VariationalSindyLayer` is a Bayesian version of the SINDy model that uses a variational inference approach to learn the model coefficients. We will use the `Laplacian` priors for the coefficients and use a polynomial library of degree 2 to learn the model.

# %%
# reshape data to fit the model
x_train = np.concatenate(x, axis=0)
dxdt_train = np.concatenate(dxdt, axis=0)
x_test = np.concatenate(x_test, axis=0)
dxdt_test = np.concatenate(dxdt_test, axis=0)

# model parameters
libraries = [
    PolynomialLibrary(2, include_bias=True),
]
dt = t[1] - t[0]

# create sindy layer
layer_params = dict(
    state_dim=x_train.shape[1],
    param_dim=0,
    feature_libraries=libraries,
    second_order=False,
    mask=None,
    kernel_regularizer=tf.keras.regularizers.L1L2(l1=0, l2=0),
)
if sindy_type == "vindy":
    sindy_layer = VindyLayer(
        beta=1e-3,
        priors=Laplace(0.0, 1.0),
        **layer_params,
    )
elif sindy_type == "sindy":
    sindy_layer = SindyLayer(
        **layer_params,
    )
else:
    raise ValueError(f"Unknown SINDy type: {sindy_type}")

# create autoencoder sindy model
model = SindyNetwork(
    sindy_layer=sindy_layer,
    x=x_train,
    l_dz=1e0,
    dt=dt,
    second_order=False,
)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss="huber")

# %% [markdown]
# Let's train the VINDy model on the (noisy) Roessler data

# %%
weights_path = os.path.join(weights_dir, ".weights.h5")

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=os.path.join(weights_path),
        save_weights_only=True,
        save_best_only=True,
        monitor="loss",
        verbose=0,
    ),
    SaveCoefficientsCallback()
]

trainhist = model.fit(
    x=[x_train, dxdt_train],
    callbacks=callbacks,
    y=None,
    epochs=500,
    batch_size=256,
    verbose=2,
)
# load best weights
model.load_weights(os.path.join(weights_path))
# apply pdf threshold
sindy_layer.pdf_thresholding(threshold=0.5)
# Out:
# Epoch 1/500
# 235/235 - 3s - 12ms/step - dz: 81.6656 - kl_sindy: 0.0098 - loss: 81.6755 - reg: 0.0000e+00 - coeffs_mean: -5.7813e-02 - coeffs_scale: -1.1300e-01
# Epoch 2/500
# 235/235 - 1s - 2ms/step - dz: 70.2228 - kl_sindy: 0.0087 - loss: 70.2316 - reg: 0.0000e+00 - coeffs_mean: -7.7186e-02 - coeffs_scale: -1.8321e-01
# Epoch 3/500
# 235/235 - 1s - 3ms/step - dz: 62.7851 - kl_sindy: 0.0081 - loss: 62.7932 - reg: 0.0000e+00 - coeffs_mean: -8.7108e-02 - coeffs_scale: -2.5726e-01
# Epoch 4/500
# 235/235 - 1s - 3ms/step - dz: 53.3906 - kl_sindy: 0.0080 - loss: 53.3986 - reg: 0.0000e+00 - coeffs_mean: -9.7801e-02 - coeffs_scale: -3.3029e-01
# Epoch 5/500
# 235/235 - 1s - 3ms/step - dz: 49.2545 - kl_sindy: 0.0081 - loss: 49.2626 - reg: 0.0000e+00 - coeffs_mean: -1.0639e-01 - coeffs_scale: -4.0346e-01
# Epoch 6/500
# 235/235 - 0s - 2ms/step - dz: 42.8325 - kl_sindy: 0.0085 - loss: 42.8410 - reg: 0.0000e+00 - coeffs_mean: -1.0615e-01 - coeffs_scale: -4.7437e-01
# Epoch 7/500
# 235/235 - 0s - 2ms/step - dz: 39.4470 - kl_sindy: 0.0091 - loss: 39.4561 - reg: 0.0000e+00 - coeffs_mean: -1.0689e-01 - coeffs_scale: -5.4549e-01
# Epoch 8/500
# 235/235 - 1s - 3ms/step - dz: 35.8639 - kl_sindy: 0.0098 - loss: 35.8738 - reg: 0.0000e+00 - coeffs_mean: -9.8948e-02 - coeffs_scale: -6.1661e-01
# Epoch 9/500
# 235/235 - 1s - 3ms/step - dz: 32.2227 - kl_sindy: 0.0107 - loss: 32.2334 - reg: 0.0000e+00 - coeffs_mean: -9.1933e-02 - coeffs_scale: -6.8641e-01
# Epoch 10/500
# 235/235 - 1s - 3ms/step - dz: 29.6522 - kl_sindy: 0.0117 - loss: 29.6639 - reg: 0.0000e+00 - coeffs_mean: -9.0943e-02 - coeffs_scale: -7.5570e-01
# Epoch 11/500
# 235/235 - 1s - 2ms/step - dz: 26.4246 - kl_sindy: 0.0128 - loss: 26.4374 - reg: 0.0000e+00 - coeffs_mean: -8.7638e-02 - coeffs_scale: -8.2394e-01
# Epoch 12/500
# 235/235 - 1s - 3ms/step - dz: 24.2617 - kl_sindy: 0.0139 - loss: 24.2756 - reg: 0.0000e+00 - coeffs_mean: -8.4269e-02 - coeffs_scale: -8.8919e-01
# Epoch 13/500
# 235/235 - 1s - 3ms/step - dz: 22.3292 - kl_sindy: 0.0151 - loss: 22.3443 - reg: 0.0000e+00 - coeffs_mean: -8.6129e-02 - coeffs_scale: -9.5675e-01
# Epoch 14/500
# 235/235 - 0s - 2ms/step - dz: 19.7870 - kl_sindy: 0.0163 - loss: 19.8033 - reg: 0.0000e+00 - coeffs_mean: -8.4166e-02 - coeffs_scale: -1.0244e+00
# Epoch 15/500
# 235/235 - 0s - 2ms/step - dz: 19.0290 - kl_sindy: 0.0177 - loss: 19.0467 - reg: 0.0000e+00 - coeffs_mean: -8.7629e-02 - coeffs_scale: -1.0902e+00
# Epoch 16/500
# 235/235 - 1s - 3ms/step - dz: 17.1767 - kl_sindy: 0.0189 - loss: 17.1957 - reg: 0.0000e+00 - coeffs_mean: -8.2067e-02 - coeffs_scale: -1.1525e+00
# Epoch 17/500
# 235/235 - 1s - 3ms/step - dz: 17.1575 - kl_sindy: 0.0203 - loss: 17.1778 - reg: 0.0000e+00 - coeffs_mean: -8.1977e-02 - coeffs_scale: -1.2217e+00
# Epoch 18/500
# 235/235 - 1s - 2ms/step - dz: 14.6575 - kl_sindy: 0.0217 - loss: 14.6792 - reg: 0.0000e+00 - coeffs_mean: -8.5951e-02 - coeffs_scale: -1.2874e+00
# Epoch 19/500
# 235/235 - 1s - 3ms/step - dz: 13.3210 - kl_sindy: 0.0231 - loss: 13.3441 - reg: 0.0000e+00 - coeffs_mean: -8.3622e-02 - coeffs_scale: -1.3490e+00
# Epoch 20/500
# 235/235 - 1s - 3ms/step - dz: 12.4154 - kl_sindy: 0.0245 - loss: 12.4399 - reg: 0.0000e+00 - coeffs_mean: -8.2265e-02 - coeffs_scale: -1.4095e+00
# Epoch 21/500
# 235/235 - 1s - 6ms/step - dz: 11.2008 - kl_sindy: 0.0259 - loss: 11.2267 - reg: 0.0000e+00 - coeffs_mean: -8.4401e-02 - coeffs_scale: -1.4716e+00
# Epoch 22/500
# 235/235 - 1s - 4ms/step - dz: 10.2530 - kl_sindy: 0.0273 - loss: 10.2803 - reg: 0.0000e+00 - coeffs_mean: -8.4510e-02 - coeffs_scale: -1.5335e+00
# Epoch 23/500
# 235/235 - 1s - 3ms/step - dz: 9.5514 - kl_sindy: 0.0288 - loss: 9.5802 - reg: 0.0000e+00 - coeffs_mean: -8.5154e-02 - coeffs_scale: -1.5947e+00
# Epoch 24/500
# 235/235 - 0s - 2ms/step - dz: 9.2242 - kl_sindy: 0.0303 - loss: 9.2545 - reg: 0.0000e+00 - coeffs_mean: -8.7691e-02 - coeffs_scale: -1.6599e+00
# Epoch 25/500
# 235/235 - 1s - 3ms/step - dz: 8.3354 - kl_sindy: 0.0319 - loss: 8.3674 - reg: 0.0000e+00 - coeffs_mean: -8.8176e-02 - coeffs_scale: -1.7227e+00
# Epoch 26/500
# 235/235 - 1s - 3ms/step - dz: 8.0289 - kl_sindy: 0.0335 - loss: 8.0623 - reg: 0.0000e+00 - coeffs_mean: -8.6557e-02 - coeffs_scale: -1.7848e+00
# Epoch 27/500
# 235/235 - 1s - 3ms/step - dz: 7.4118 - kl_sindy: 0.0350 - loss: 7.4468 - reg: 0.0000e+00 - coeffs_mean: -8.4386e-02 - coeffs_scale: -1.8442e+00
# Epoch 28/500
# 235/235 - 0s - 2ms/step - dz: 7.0734 - kl_sindy: 0.0365 - loss: 7.1100 - reg: 0.0000e+00 - coeffs_mean: -8.4339e-02 - coeffs_scale: -1.9081e+00
# Epoch 29/500
# 235/235 - 1s - 4ms/step - dz: 6.4205 - kl_sindy: 0.0382 - loss: 6.4587 - reg: 0.0000e+00 - coeffs_mean: -8.2039e-02 - coeffs_scale: -1.9702e+00
# Epoch 30/500
# 235/235 - 1s - 2ms/step - dz: 5.7667 - kl_sindy: 0.0398 - loss: 5.8065 - reg: 0.0000e+00 - coeffs_mean: -9.0089e-02 - coeffs_scale: -2.0321e+00
# Epoch 31/500
# 235/235 - 1s - 2ms/step - dz: 5.6091 - kl_sindy: 0.0415 - loss: 5.6506 - reg: 0.0000e+00 - coeffs_mean: -8.7350e-02 - coeffs_scale: -2.0952e+00
# Epoch 32/500
# 235/235 - 1s - 3ms/step - dz: 5.2213 - kl_sindy: 0.0431 - loss: 5.2645 - reg: 0.0000e+00 - coeffs_mean: -8.4976e-02 - coeffs_scale: -2.1564e+00
# Epoch 33/500
# 235/235 - 1s - 3ms/step - dz: 5.1114 - kl_sindy: 0.0448 - loss: 5.1562 - reg: 0.0000e+00 - coeffs_mean: -8.5094e-02 - coeffs_scale: -2.2186e+00
# Epoch 34/500
# 235/235 - 1s - 2ms/step - dz: 4.6376 - kl_sindy: 0.0465 - loss: 4.6841 - reg: 0.0000e+00 - coeffs_mean: -8.5751e-02 - coeffs_scale: -2.2806e+00
# Epoch 35/500
# 235/235 - 0s - 2ms/step - dz: 4.4106 - kl_sindy: 0.0481 - loss: 4.4587 - reg: 0.0000e+00 - coeffs_mean: -8.6290e-02 - coeffs_scale: -2.3434e+00
# Epoch 36/500
# 235/235 - 1s - 3ms/step - dz: 4.0598 - kl_sindy: 0.0499 - loss: 4.1096 - reg: 0.0000e+00 - coeffs_mean: -8.5848e-02 - coeffs_scale: -2.4041e+00
# Epoch 37/500
# 235/235 - 1s - 3ms/step - dz: 3.8946 - kl_sindy: 0.0515 - loss: 3.9461 - reg: 0.0000e+00 - coeffs_mean: -8.6152e-02 - coeffs_scale: -2.4635e+00
# Epoch 38/500
# 235/235 - 0s - 2ms/step - dz: 3.6429 - kl_sindy: 0.0532 - loss: 3.6960 - reg: 0.0000e+00 - coeffs_mean: -8.6995e-02 - coeffs_scale: -2.5225e+00
# Epoch 39/500
# 235/235 - 1s - 3ms/step - dz: 3.4371 - kl_sindy: 0.0549 - loss: 3.4919 - reg: 0.0000e+00 - coeffs_mean: -8.7723e-02 - coeffs_scale: -2.5819e+00
# Epoch 40/500
# 235/235 - 1s - 3ms/step - dz: 3.2347 - kl_sindy: 0.0565 - loss: 3.2913 - reg: 0.0000e+00 - coeffs_mean: -8.6483e-02 - coeffs_scale: -2.6389e+00
# Epoch 41/500
# 235/235 - 0s - 2ms/step - dz: 3.1792 - kl_sindy: 0.0582 - loss: 3.2374 - reg: 0.0000e+00 - coeffs_mean: -8.5944e-02 - coeffs_scale: -2.6990e+00
# Epoch 42/500
# 235/235 - 0s - 2ms/step - dz: 2.9617 - kl_sindy: 0.0598 - loss: 3.0215 - reg: 0.0000e+00 - coeffs_mean: -8.9857e-02 - coeffs_scale: -2.7566e+00
# Epoch 43/500
# 235/235 - 0s - 2ms/step - dz: 2.8074 - kl_sindy: 0.0615 - loss: 2.8689 - reg: 0.0000e+00 - coeffs_mean: -9.0826e-02 - coeffs_scale: -2.8147e+00
# Epoch 44/500
# 235/235 - 1s - 3ms/step - dz: 2.6987 - kl_sindy: 0.0632 - loss: 2.7619 - reg: 0.0000e+00 - coeffs_mean: -8.8098e-02 - coeffs_scale: -2.8728e+00
# Epoch 45/500
# 235/235 - 0s - 2ms/step - dz: 2.6101 - kl_sindy: 0.0649 - loss: 2.6750 - reg: 0.0000e+00 - coeffs_mean: -8.5405e-02 - coeffs_scale: -2.9330e+00
# Epoch 46/500
# 235/235 - 1s - 3ms/step - dz: 2.4284 - kl_sindy: 0.0666 - loss: 2.4950 - reg: 0.0000e+00 - coeffs_mean: -8.8157e-02 - coeffs_scale: -2.9899e+00
# Epoch 47/500
# 235/235 - 1s - 3ms/step - dz: 2.3769 - kl_sindy: 0.0683 - loss: 2.4452 - reg: 0.0000e+00 - coeffs_mean: -8.9326e-02 - coeffs_scale: -3.0474e+00
# Epoch 48/500
# 235/235 - 1s - 3ms/step - dz: 2.2879 - kl_sindy: 0.0700 - loss: 2.3579 - reg: 0.0000e+00 - coeffs_mean: -9.0400e-02 - coeffs_scale: -3.1052e+00
# Epoch 49/500
# 235/235 - 0s - 2ms/step - dz: 2.2166 - kl_sindy: 0.0716 - loss: 2.2882 - reg: 0.0000e+00 - coeffs_mean: -9.0062e-02 - coeffs_scale: -3.1605e+00
# Epoch 50/500
# 235/235 - 0s - 2ms/step - dz: 2.1204 - kl_sindy: 0.0733 - loss: 2.1936 - reg: 0.0000e+00 - coeffs_mean: -9.1457e-02 - coeffs_scale: -3.2149e+00
# Epoch 51/500
# 235/235 - 1s - 3ms/step - dz: 2.0375 - kl_sindy: 0.0748 - loss: 2.1124 - reg: 0.0000e+00 - coeffs_mean: -9.0723e-02 - coeffs_scale: -3.2691e+00
# Epoch 52/500
# 235/235 - 0s - 2ms/step - dz: 1.9874 - kl_sindy: 0.0764 - loss: 2.0638 - reg: 0.0000e+00 - coeffs_mean: -9.3222e-02 - coeffs_scale: -3.3228e+00
# Epoch 53/500
# 235/235 - 1s - 3ms/step - dz: 1.9234 - kl_sindy: 0.0780 - loss: 2.0014 - reg: 0.0000e+00 - coeffs_mean: -9.3886e-02 - coeffs_scale: -3.3755e+00
# Epoch 54/500
# 235/235 - 1s - 3ms/step - dz: 1.8804 - kl_sindy: 0.0796 - loss: 1.9600 - reg: 0.0000e+00 - coeffs_mean: -9.2945e-02 - coeffs_scale: -3.4284e+00
# Epoch 55/500
# 235/235 - 1s - 3ms/step - dz: 1.8194 - kl_sindy: 0.0812 - loss: 1.9005 - reg: 0.0000e+00 - coeffs_mean: -9.5158e-02 - coeffs_scale: -3.4795e+00
# Epoch 56/500
# 235/235 - 1s - 3ms/step - dz: 1.8283 - kl_sindy: 0.0828 - loss: 1.9111 - reg: 0.0000e+00 - coeffs_mean: -9.5167e-02 - coeffs_scale: -3.5356e+00
# Epoch 57/500
# 235/235 - 1s - 2ms/step - dz: 1.7409 - kl_sindy: 0.0845 - loss: 1.8253 - reg: 0.0000e+00 - coeffs_mean: -9.8658e-02 - coeffs_scale: -3.5870e+00
# Epoch 58/500
# 235/235 - 1s - 3ms/step - dz: 1.6978 - kl_sindy: 0.0860 - loss: 1.7838 - reg: 0.0000e+00 - coeffs_mean: -9.8580e-02 - coeffs_scale: -3.6377e+00
# Epoch 59/500
# 235/235 - 0s - 2ms/step - dz: 1.6583 - kl_sindy: 0.0876 - loss: 1.7459 - reg: 0.0000e+00 - coeffs_mean: -9.8887e-02 - coeffs_scale: -3.6884e+00
# Epoch 60/500
# 235/235 - 1s - 2ms/step - dz: 1.6269 - kl_sindy: 0.0890 - loss: 1.7160 - reg: 0.0000e+00 - coeffs_mean: -9.9368e-02 - coeffs_scale: -3.7351e+00
# Epoch 61/500
# 235/235 - 1s - 3ms/step - dz: 1.6246 - kl_sindy: 0.0905 - loss: 1.7152 - reg: 0.0000e+00 - coeffs_mean: -1.0237e-01 - coeffs_scale: -3.7851e+00
# Epoch 62/500
# 235/235 - 1s - 3ms/step - dz: 1.5868 - kl_sindy: 0.0920 - loss: 1.6788 - reg: 0.0000e+00 - coeffs_mean: -1.0644e-01 - coeffs_scale: -3.8343e+00
# Epoch 63/500
# 235/235 - 1s - 3ms/step - dz: 1.5514 - kl_sindy: 0.0935 - loss: 1.6449 - reg: 0.0000e+00 - coeffs_mean: -1.0549e-01 - coeffs_scale: -3.8814e+00
# Epoch 64/500
# 235/235 - 1s - 3ms/step - dz: 1.5388 - kl_sindy: 0.0950 - loss: 1.6338 - reg: 0.0000e+00 - coeffs_mean: -1.0829e-01 - coeffs_scale: -3.9283e+00
# Epoch 65/500
# 235/235 - 0s - 2ms/step - dz: 1.5120 - kl_sindy: 0.0964 - loss: 1.6085 - reg: 0.0000e+00 - coeffs_mean: -1.1113e-01 - coeffs_scale: -3.9726e+00
# Epoch 66/500
# 235/235 - 1s - 3ms/step - dz: 1.5005 - kl_sindy: 0.0978 - loss: 1.5983 - reg: 0.0000e+00 - coeffs_mean: -1.1104e-01 - coeffs_scale: -4.0185e+00
# Epoch 67/500
# 235/235 - 1s - 3ms/step - dz: 1.4863 - kl_sindy: 0.0993 - loss: 1.5856 - reg: 0.0000e+00 - coeffs_mean: -1.1217e-01 - coeffs_scale: -4.0653e+00
# Epoch 68/500
# 235/235 - 0s - 2ms/step - dz: 1.4550 - kl_sindy: 0.1006 - loss: 1.5557 - reg: 0.0000e+00 - coeffs_mean: -1.1296e-01 - coeffs_scale: -4.1091e+00
# Epoch 69/500
# 235/235 - 0s - 2ms/step - dz: 1.4515 - kl_sindy: 0.1020 - loss: 1.5535 - reg: 0.0000e+00 - coeffs_mean: -1.1573e-01 - coeffs_scale: -4.1539e+00
# Epoch 70/500
# 235/235 - 0s - 2ms/step - dz: 1.4329 - kl_sindy: 0.1034 - loss: 1.5363 - reg: 0.0000e+00 - coeffs_mean: -1.1680e-01 - coeffs_scale: -4.1957e+00
# Epoch 71/500
# 235/235 - 1s - 3ms/step - dz: 1.4204 - kl_sindy: 0.1046 - loss: 1.5250 - reg: 0.0000e+00 - coeffs_mean: -1.1859e-01 - coeffs_scale: -4.2347e+00
# Epoch 72/500
# 235/235 - 0s - 2ms/step - dz: 1.4060 - kl_sindy: 0.1059 - loss: 1.5118 - reg: 0.0000e+00 - coeffs_mean: -1.2118e-01 - coeffs_scale: -4.2743e+00
# Epoch 73/500
# 235/235 - 0s - 2ms/step - dz: 1.3967 - kl_sindy: 0.1071 - loss: 1.5038 - reg: 0.0000e+00 - coeffs_mean: -1.2195e-01 - coeffs_scale: -4.3142e+00
# Epoch 74/500
# 235/235 - 0s - 2ms/step - dz: 1.3800 - kl_sindy: 0.1083 - loss: 1.4884 - reg: 0.0000e+00 - coeffs_mean: -1.2436e-01 - coeffs_scale: -4.3504e+00
# Epoch 75/500
# 235/235 - 1s - 3ms/step - dz: 1.3745 - kl_sindy: 0.1095 - loss: 1.4840 - reg: 0.0000e+00 - coeffs_mean: -1.2522e-01 - coeffs_scale: -4.3859e+00
# Epoch 76/500
# 235/235 - 0s - 2ms/step - dz: 1.3692 - kl_sindy: 0.1106 - loss: 1.4798 - reg: 0.0000e+00 - coeffs_mean: -1.2701e-01 - coeffs_scale: -4.4231e+00
# Epoch 77/500
# 235/235 - 1s - 3ms/step - dz: 1.3625 - kl_sindy: 0.1118 - loss: 1.4742 - reg: 0.0000e+00 - coeffs_mean: -1.2844e-01 - coeffs_scale: -4.4583e+00
# Epoch 78/500
# 235/235 - 0s - 2ms/step - dz: 1.3576 - kl_sindy: 0.1129 - loss: 1.4705 - reg: 0.0000e+00 - coeffs_mean: -1.3048e-01 - coeffs_scale: -4.4940e+00
# Epoch 79/500
# 235/235 - 1s - 2ms/step - dz: 1.3497 - kl_sindy: 0.1140 - loss: 1.4637 - reg: 0.0000e+00 - coeffs_mean: -1.3175e-01 - coeffs_scale: -4.5289e+00
# Epoch 80/500
# 235/235 - 1s - 2ms/step - dz: 1.3411 - kl_sindy: 0.1151 - loss: 1.4562 - reg: 0.0000e+00 - coeffs_mean: -1.3271e-01 - coeffs_scale: -4.5603e+00
# Epoch 81/500
# 235/235 - 1s - 3ms/step - dz: 1.3366 - kl_sindy: 0.1161 - loss: 1.4527 - reg: 0.0000e+00 - coeffs_mean: -1.3569e-01 - coeffs_scale: -4.5925e+00
# Epoch 82/500
# 235/235 - 1s - 5ms/step - dz: 1.3310 - kl_sindy: 0.1171 - loss: 1.4481 - reg: 0.0000e+00 - coeffs_mean: -1.3686e-01 - coeffs_scale: -4.6255e+00
# Epoch 83/500
# 235/235 - 0s - 2ms/step - dz: 1.3256 - kl_sindy: 0.1181 - loss: 1.4437 - reg: 0.0000e+00 - coeffs_mean: -1.3873e-01 - coeffs_scale: -4.6566e+00
# Epoch 84/500
# 235/235 - 1s - 3ms/step - dz: 1.3193 - kl_sindy: 0.1191 - loss: 1.4384 - reg: 0.0000e+00 - coeffs_mean: -1.3924e-01 - coeffs_scale: -4.6863e+00
# Epoch 85/500
# 235/235 - 1s - 3ms/step - dz: 1.3160 - kl_sindy: 0.1200 - loss: 1.4360 - reg: 0.0000e+00 - coeffs_mean: -1.3968e-01 - coeffs_scale: -4.7134e+00
# Epoch 86/500
# 235/235 - 1s - 3ms/step - dz: 1.3123 - kl_sindy: 0.1208 - loss: 1.4331 - reg: 0.0000e+00 - coeffs_mean: -1.4137e-01 - coeffs_scale: -4.7386e+00
# Epoch 87/500
# 235/235 - 1s - 3ms/step - dz: 1.3077 - kl_sindy: 0.1216 - loss: 1.4292 - reg: 0.0000e+00 - coeffs_mean: -1.4223e-01 - coeffs_scale: -4.7619e+00
# Epoch 88/500
# 235/235 - 1s - 3ms/step - dz: 1.3069 - kl_sindy: 0.1223 - loss: 1.4292 - reg: 0.0000e+00 - coeffs_mean: -1.4315e-01 - coeffs_scale: -4.7883e+00
# Epoch 89/500
# 235/235 - 0s - 2ms/step - dz: 1.3067 - kl_sindy: 0.1231 - loss: 1.4298 - reg: 0.0000e+00 - coeffs_mean: -1.4525e-01 - coeffs_scale: -4.8118e+00
# Epoch 90/500
# 235/235 - 1s - 3ms/step - dz: 1.3020 - kl_sindy: 0.1238 - loss: 1.4258 - reg: 0.0000e+00 - coeffs_mean: -1.4686e-01 - coeffs_scale: -4.8325e+00
# Epoch 91/500
# 235/235 - 1s - 3ms/step - dz: 1.2963 - kl_sindy: 0.1245 - loss: 1.4208 - reg: 0.0000e+00 - coeffs_mean: -1.4704e-01 - coeffs_scale: -4.8527e+00
# Epoch 92/500
# 235/235 - 1s - 3ms/step - dz: 1.2970 - kl_sindy: 0.1252 - loss: 1.4222 - reg: 0.0000e+00 - coeffs_mean: -1.4944e-01 - coeffs_scale: -4.8745e+00
# Epoch 93/500
# 235/235 - 0s - 2ms/step - dz: 1.2945 - kl_sindy: 0.1259 - loss: 1.4204 - reg: 0.0000e+00 - coeffs_mean: -1.4965e-01 - coeffs_scale: -4.8967e+00
# Epoch 94/500
# 235/235 - 0s - 2ms/step - dz: 1.2917 - kl_sindy: 0.1265 - loss: 1.4182 - reg: 0.0000e+00 - coeffs_mean: -1.5048e-01 - coeffs_scale: -4.9129e+00
# Epoch 95/500
# 235/235 - 0s - 2ms/step - dz: 1.2912 - kl_sindy: 0.1270 - loss: 1.4182 - reg: 0.0000e+00 - coeffs_mean: -1.5121e-01 - coeffs_scale: -4.9306e+00
# Epoch 96/500
# 235/235 - 0s - 2ms/step - dz: 1.2869 - kl_sindy: 0.1276 - loss: 1.4145 - reg: 0.0000e+00 - coeffs_mean: -1.5348e-01 - coeffs_scale: -4.9463e+00
# Epoch 97/500
# 235/235 - 1s - 3ms/step - dz: 1.2852 - kl_sindy: 0.1280 - loss: 1.4132 - reg: 0.0000e+00 - coeffs_mean: -1.5274e-01 - coeffs_scale: -4.9597e+00
# Epoch 98/500
# 235/235 - 0s - 1ms/step - dz: 1.2891 - kl_sindy: 0.1286 - loss: 1.4177 - reg: 0.0000e+00 - coeffs_mean: -1.5308e-01 - coeffs_scale: -4.9765e+00
# Epoch 99/500
# 235/235 - 0s - 2ms/step - dz: 1.2825 - kl_sindy: 0.1290 - loss: 1.4115 - reg: 0.0000e+00 - coeffs_mean: -1.5359e-01 - coeffs_scale: -4.9871e+00
# Epoch 100/500
# 235/235 - 0s - 2ms/step - dz: 1.2814 - kl_sindy: 0.1293 - loss: 1.4107 - reg: 0.0000e+00 - coeffs_mean: -1.5545e-01 - coeffs_scale: -4.9973e+00
# Epoch 101/500
# 235/235 - 1s - 3ms/step - dz: 1.2810 - kl_sindy: 0.1296 - loss: 1.4106 - reg: 0.0000e+00 - coeffs_mean: -1.5583e-01 - coeffs_scale: -5.0052e+00
# Epoch 102/500
# 235/235 - 1s - 3ms/step - dz: 1.2841 - kl_sindy: 0.1300 - loss: 1.4141 - reg: 0.0000e+00 - coeffs_mean: -1.5579e-01 - coeffs_scale: -5.0194e+00
# Epoch 103/500
# 235/235 - 1s - 3ms/step - dz: 1.2830 - kl_sindy: 0.1304 - loss: 1.4134 - reg: 0.0000e+00 - coeffs_mean: -1.5587e-01 - coeffs_scale: -5.0317e+00
# Epoch 104/500
# 235/235 - 1s - 3ms/step - dz: 1.2800 - kl_sindy: 0.1307 - loss: 1.4107 - reg: 0.0000e+00 - coeffs_mean: -1.5879e-01 - coeffs_scale: -5.0398e+00
# Epoch 105/500
# 235/235 - 1s - 3ms/step - dz: 1.2818 - kl_sindy: 0.1310 - loss: 1.4128 - reg: 0.0000e+00 - coeffs_mean: -1.5819e-01 - coeffs_scale: -5.0500e+00
# Epoch 106/500
# 235/235 - 1s - 3ms/step - dz: 1.2823 - kl_sindy: 0.1313 - loss: 1.4136 - reg: 0.0000e+00 - coeffs_mean: -1.5986e-01 - coeffs_scale: -5.0595e+00
# Epoch 107/500
# 235/235 - 0s - 2ms/step - dz: 1.2768 - kl_sindy: 0.1316 - loss: 1.4084 - reg: 0.0000e+00 - coeffs_mean: -1.5765e-01 - coeffs_scale: -5.0650e+00
# Epoch 108/500
# 235/235 - 0s - 1ms/step - dz: 1.2795 - kl_sindy: 0.1317 - loss: 1.4112 - reg: 0.0000e+00 - coeffs_mean: -1.5866e-01 - coeffs_scale: -5.0694e+00
# Epoch 109/500
# 235/235 - 1s - 3ms/step - dz: 1.2782 - kl_sindy: 0.1319 - loss: 1.4101 - reg: 0.0000e+00 - coeffs_mean: -1.5970e-01 - coeffs_scale: -5.0750e+00
# Epoch 110/500
# 235/235 - 0s - 1ms/step - dz: 1.2764 - kl_sindy: 0.1321 - loss: 1.4084 - reg: 0.0000e+00 - coeffs_mean: -1.5888e-01 - coeffs_scale: -5.0807e+00
# Epoch 111/500
# 235/235 - 1s - 3ms/step - dz: 1.2782 - kl_sindy: 0.1322 - loss: 1.4104 - reg: 0.0000e+00 - coeffs_mean: -1.5991e-01 - coeffs_scale: -5.0851e+00
# Epoch 112/500
# 235/235 - 1s - 3ms/step - dz: 1.2783 - kl_sindy: 0.1324 - loss: 1.4107 - reg: 0.0000e+00 - coeffs_mean: -1.6012e-01 - coeffs_scale: -5.0895e+00
# Epoch 113/500
# 235/235 - 1s - 3ms/step - dz: 1.2767 - kl_sindy: 0.1325 - loss: 1.4092 - reg: 0.0000e+00 - coeffs_mean: -1.6016e-01 - coeffs_scale: -5.0940e+00
# Epoch 114/500
# 235/235 - 1s - 3ms/step - dz: 1.2760 - kl_sindy: 0.1327 - loss: 1.4087 - reg: 0.0000e+00 - coeffs_mean: -1.6188e-01 - coeffs_scale: -5.0967e+00
# Epoch 115/500
# 235/235 - 0s - 1ms/step - dz: 1.2777 - kl_sindy: 0.1327 - loss: 1.4104 - reg: 0.0000e+00 - coeffs_mean: -1.6212e-01 - coeffs_scale: -5.0986e+00
# Epoch 116/500
# 235/235 - 1s - 3ms/step - dz: 1.2771 - kl_sindy: 0.1329 - loss: 1.4100 - reg: 0.0000e+00 - coeffs_mean: -1.6190e-01 - coeffs_scale: -5.1044e+00
# Epoch 117/500
# 235/235 - 1s - 3ms/step - dz: 1.2773 - kl_sindy: 0.1330 - loss: 1.4103 - reg: 0.0000e+00 - coeffs_mean: -1.6177e-01 - coeffs_scale: -5.1105e+00
# Epoch 118/500
# 235/235 - 0s - 2ms/step - dz: 1.2753 - kl_sindy: 0.1331 - loss: 1.4084 - reg: 0.0000e+00 - coeffs_mean: -1.6310e-01 - coeffs_scale: -5.1093e+00
# Epoch 119/500
# 235/235 - 0s - 1ms/step - dz: 1.2770 - kl_sindy: 0.1332 - loss: 1.4102 - reg: 0.0000e+00 - coeffs_mean: -1.6270e-01 - coeffs_scale: -5.1125e+00
# Epoch 120/500
# 235/235 - 1s - 3ms/step - dz: 1.2767 - kl_sindy: 0.1333 - loss: 1.4100 - reg: 0.0000e+00 - coeffs_mean: -1.6299e-01 - coeffs_scale: -5.1158e+00
# Epoch 121/500
# 235/235 - 1s - 3ms/step - dz: 1.2762 - kl_sindy: 0.1333 - loss: 1.4095 - reg: 0.0000e+00 - coeffs_mean: -1.6245e-01 - coeffs_scale: -5.1181e+00
# Epoch 122/500
# 235/235 - 1s - 3ms/step - dz: 1.2749 - kl_sindy: 0.1334 - loss: 1.4083 - reg: 0.0000e+00 - coeffs_mean: -1.6267e-01 - coeffs_scale: -5.1200e+00
# Epoch 123/500
# 235/235 - 0s - 1ms/step - dz: 1.2756 - kl_sindy: 0.1335 - loss: 1.4090 - reg: 0.0000e+00 - coeffs_mean: -1.6236e-01 - coeffs_scale: -5.1208e+00
# Epoch 124/500
# 235/235 - 1s - 3ms/step - dz: 1.2741 - kl_sindy: 0.1334 - loss: 1.4075 - reg: 0.0000e+00 - coeffs_mean: -1.6285e-01 - coeffs_scale: -5.1160e+00
# Epoch 125/500
# 235/235 - 1s - 3ms/step - dz: 1.2760 - kl_sindy: 0.1333 - loss: 1.4093 - reg: 0.0000e+00 - coeffs_mean: -1.6236e-01 - coeffs_scale: -5.1168e+00
# Epoch 126/500
# 235/235 - 1s - 3ms/step - dz: 1.2761 - kl_sindy: 0.1334 - loss: 1.4095 - reg: 0.0000e+00 - coeffs_mean: -1.6289e-01 - coeffs_scale: -5.1181e+00
# Epoch 127/500
# 235/235 - 1s - 3ms/step - dz: 1.2762 - kl_sindy: 0.1335 - loss: 1.4097 - reg: 0.0000e+00 - coeffs_mean: -1.6300e-01 - coeffs_scale: -5.1200e+00
# Epoch 128/500
# 235/235 - 1s - 2ms/step - dz: 1.2761 - kl_sindy: 0.1335 - loss: 1.4096 - reg: 0.0000e+00 - coeffs_mean: -1.6364e-01 - coeffs_scale: -5.1223e+00
# Epoch 129/500
# 235/235 - 1s - 2ms/step - dz: 1.2745 - kl_sindy: 0.1336 - loss: 1.4080 - reg: 0.0000e+00 - coeffs_mean: -1.6465e-01 - coeffs_scale: -5.1189e+00
# Epoch 130/500
# 235/235 - 1s - 3ms/step - dz: 1.2756 - kl_sindy: 0.1335 - loss: 1.4091 - reg: 0.0000e+00 - coeffs_mean: -1.6305e-01 - coeffs_scale: -5.1191e+00
# Epoch 131/500
# 235/235 - 0s - 2ms/step - dz: 1.2763 - kl_sindy: 0.1335 - loss: 1.4098 - reg: 0.0000e+00 - coeffs_mean: -1.6398e-01 - coeffs_scale: -5.1218e+00
# Epoch 132/500
# 235/235 - 1s - 3ms/step - dz: 1.2748 - kl_sindy: 0.1336 - loss: 1.4083 - reg: 0.0000e+00 - coeffs_mean: -1.6402e-01 - coeffs_scale: -5.1204e+00
# Epoch 133/500
# 235/235 - 1s - 3ms/step - dz: 1.2746 - kl_sindy: 0.1335 - loss: 1.4081 - reg: 0.0000e+00 - coeffs_mean: -1.6404e-01 - coeffs_scale: -5.1185e+00
# Epoch 134/500
# 235/235 - 1s - 3ms/step - dz: 1.2744 - kl_sindy: 0.1334 - loss: 1.4078 - reg: 0.0000e+00 - coeffs_mean: -1.6360e-01 - coeffs_scale: -5.1170e+00
# Epoch 135/500
# 235/235 - 0s - 2ms/step - dz: 1.2774 - kl_sindy: 0.1334 - loss: 1.4108 - reg: 0.0000e+00 - coeffs_mean: -1.6468e-01 - coeffs_scale: -5.1197e+00
# Epoch 136/500
# 235/235 - 1s - 3ms/step - dz: 1.2740 - kl_sindy: 0.1335 - loss: 1.4075 - reg: 0.0000e+00 - coeffs_mean: -1.6496e-01 - coeffs_scale: -5.1206e+00
# Epoch 137/500
# 235/235 - 1s - 3ms/step - dz: 1.2774 - kl_sindy: 0.1336 - loss: 1.4110 - reg: 0.0000e+00 - coeffs_mean: -1.6332e-01 - coeffs_scale: -5.1242e+00
# Epoch 138/500
# 235/235 - 1s - 3ms/step - dz: 1.2761 - kl_sindy: 0.1336 - loss: 1.4097 - reg: 0.0000e+00 - coeffs_mean: -1.6437e-01 - coeffs_scale: -5.1247e+00
# Epoch 139/500
# 235/235 - 1s - 3ms/step - dz: 1.2760 - kl_sindy: 0.1337 - loss: 1.4097 - reg: 0.0000e+00 - coeffs_mean: -1.6390e-01 - coeffs_scale: -5.1254e+00
# Epoch 140/500
# 235/235 - 1s - 3ms/step - dz: 1.2765 - kl_sindy: 0.1337 - loss: 1.4102 - reg: 0.0000e+00 - coeffs_mean: -1.6524e-01 - coeffs_scale: -5.1265e+00
# Epoch 141/500
# 235/235 - 1s - 3ms/step - dz: 1.2763 - kl_sindy: 0.1338 - loss: 1.4101 - reg: 0.0000e+00 - coeffs_mean: -1.6571e-01 - coeffs_scale: -5.1302e+00
# Epoch 142/500
# 235/235 - 1s - 3ms/step - dz: 1.2757 - kl_sindy: 0.1338 - loss: 1.4095 - reg: 0.0000e+00 - coeffs_mean: -1.6425e-01 - coeffs_scale: -5.1302e+00
# Epoch 143/500
# 235/235 - 1s - 3ms/step - dz: 1.2733 - kl_sindy: 0.1338 - loss: 1.4071 - reg: 0.0000e+00 - coeffs_mean: -1.6433e-01 - coeffs_scale: -5.1246e+00
# Epoch 144/500
# 235/235 - 0s - 1ms/step - dz: 1.2758 - kl_sindy: 0.1337 - loss: 1.4095 - reg: 0.0000e+00 - coeffs_mean: -1.6563e-01 - coeffs_scale: -5.1253e+00
# Epoch 145/500
# 235/235 - 1s - 3ms/step - dz: 1.2766 - kl_sindy: 0.1337 - loss: 1.4104 - reg: 0.0000e+00 - coeffs_mean: -1.6447e-01 - coeffs_scale: -5.1297e+00
# Epoch 146/500
# 235/235 - 0s - 1ms/step - dz: 1.2788 - kl_sindy: 0.1339 - loss: 1.4127 - reg: 0.0000e+00 - coeffs_mean: -1.6483e-01 - coeffs_scale: -5.1339e+00
# Epoch 147/500
# 235/235 - 1s - 3ms/step - dz: 1.2736 - kl_sindy: 0.1338 - loss: 1.4074 - reg: 0.0000e+00 - coeffs_mean: -1.6502e-01 - coeffs_scale: -5.1281e+00
# Epoch 148/500
# 235/235 - 0s - 2ms/step - dz: 1.2751 - kl_sindy: 0.1338 - loss: 1.4089 - reg: 0.0000e+00 - coeffs_mean: -1.6402e-01 - coeffs_scale: -5.1277e+00
# Epoch 149/500
# 235/235 - 1s - 2ms/step - dz: 1.2751 - kl_sindy: 0.1338 - loss: 1.4089 - reg: 0.0000e+00 - coeffs_mean: -1.6470e-01 - coeffs_scale: -5.1285e+00
# Epoch 150/500
# 235/235 - 1s - 2ms/step - dz: 1.2748 - kl_sindy: 0.1338 - loss: 1.4086 - reg: 0.0000e+00 - coeffs_mean: -1.6445e-01 - coeffs_scale: -5.1277e+00
# Epoch 151/500
# 235/235 - 1s - 3ms/step - dz: 1.2769 - kl_sindy: 0.1338 - loss: 1.4107 - reg: 0.0000e+00 - coeffs_mean: -1.6500e-01 - coeffs_scale: -5.1307e+00
# Epoch 152/500
# 235/235 - 1s - 3ms/step - dz: 1.2761 - kl_sindy: 0.1339 - loss: 1.4100 - reg: 0.0000e+00 - coeffs_mean: -1.6525e-01 - coeffs_scale: -5.1323e+00
# Epoch 153/500
# 235/235 - 1s - 2ms/step - dz: 1.2751 - kl_sindy: 0.1339 - loss: 1.4090 - reg: 0.0000e+00 - coeffs_mean: -1.6510e-01 - coeffs_scale: -5.1310e+00
# Epoch 154/500
# 235/235 - 1s - 2ms/step - dz: 1.2744 - kl_sindy: 0.1338 - loss: 1.4083 - reg: 0.0000e+00 - coeffs_mean: -1.6488e-01 - coeffs_scale: -5.1289e+00
# Epoch 155/500
# 235/235 - 0s - 2ms/step - dz: 1.2771 - kl_sindy: 0.1339 - loss: 1.4109 - reg: 0.0000e+00 - coeffs_mean: -1.6475e-01 - coeffs_scale: -5.1320e+00
# Epoch 156/500
# 235/235 - 0s - 1ms/step - dz: 1.2743 - kl_sindy: 0.1339 - loss: 1.4082 - reg: 0.0000e+00 - coeffs_mean: -1.6508e-01 - coeffs_scale: -5.1313e+00
# Epoch 157/500
# 235/235 - 1s - 3ms/step - dz: 1.2769 - kl_sindy: 0.1339 - loss: 1.4107 - reg: 0.0000e+00 - coeffs_mean: -1.6553e-01 - coeffs_scale: -5.1323e+00
# Epoch 158/500
# 235/235 - 1s - 3ms/step - dz: 1.2737 - kl_sindy: 0.1339 - loss: 1.4075 - reg: 0.0000e+00 - coeffs_mean: -1.6372e-01 - coeffs_scale: -5.1292e+00
# Epoch 159/500
# 235/235 - 0s - 1ms/step - dz: 1.2751 - kl_sindy: 0.1338 - loss: 1.4088 - reg: 0.0000e+00 - coeffs_mean: -1.6508e-01 - coeffs_scale: -5.1265e+00
# Epoch 160/500
# 235/235 - 0s - 2ms/step - dz: 1.2759 - kl_sindy: 0.1338 - loss: 1.4097 - reg: 0.0000e+00 - coeffs_mean: -1.6399e-01 - coeffs_scale: -5.1293e+00
# Epoch 161/500
# 235/235 - 1s - 3ms/step - dz: 1.2738 - kl_sindy: 0.1338 - loss: 1.4075 - reg: 0.0000e+00 - coeffs_mean: -1.6532e-01 - coeffs_scale: -5.1278e+00
# Epoch 162/500
# 235/235 - 1s - 3ms/step - dz: 1.2763 - kl_sindy: 0.1338 - loss: 1.4101 - reg: 0.0000e+00 - coeffs_mean: -1.6557e-01 - coeffs_scale: -5.1290e+00
# Epoch 163/500
# 235/235 - 1s - 3ms/step - dz: 1.2757 - kl_sindy: 0.1338 - loss: 1.4095 - reg: 0.0000e+00 - coeffs_mean: -1.6454e-01 - coeffs_scale: -5.1286e+00
# Epoch 164/500
# 235/235 - 0s - 2ms/step - dz: 1.2779 - kl_sindy: 0.1340 - loss: 1.4119 - reg: 0.0000e+00 - coeffs_mean: -1.6427e-01 - coeffs_scale: -5.1366e+00
# Epoch 165/500
# 235/235 - 0s - 1ms/step - dz: 1.2742 - kl_sindy: 0.1339 - loss: 1.4082 - reg: 0.0000e+00 - coeffs_mean: -1.6540e-01 - coeffs_scale: -5.1324e+00
# Epoch 166/500
# 235/235 - 1s - 3ms/step - dz: 1.2762 - kl_sindy: 0.1339 - loss: 1.4101 - reg: 0.0000e+00 - coeffs_mean: -1.6581e-01 - coeffs_scale: -5.1329e+00
# Epoch 167/500
# 235/235 - 1s - 3ms/step - dz: 1.2746 - kl_sindy: 0.1339 - loss: 1.4084 - reg: 0.0000e+00 - coeffs_mean: -1.6462e-01 - coeffs_scale: -5.1300e+00
# Epoch 168/500
# 235/235 - 0s - 1ms/step - dz: 1.2741 - kl_sindy: 0.1338 - loss: 1.4079 - reg: 0.0000e+00 - coeffs_mean: -1.6513e-01 - coeffs_scale: -5.1270e+00
# Epoch 169/500
# 235/235 - 1s - 3ms/step - dz: 1.2752 - kl_sindy: 0.1337 - loss: 1.4090 - reg: 0.0000e+00 - coeffs_mean: -1.6482e-01 - coeffs_scale: -5.1243e+00
# Epoch 170/500
# 235/235 - 1s - 3ms/step - dz: 1.2762 - kl_sindy: 0.1338 - loss: 1.4099 - reg: 0.0000e+00 - coeffs_mean: -1.6528e-01 - coeffs_scale: -5.1285e+00
# Epoch 171/500
# 235/235 - 0s - 2ms/step - dz: 1.2733 - kl_sindy: 0.1337 - loss: 1.4071 - reg: 0.0000e+00 - coeffs_mean: -1.6551e-01 - coeffs_scale: -5.1246e+00
# Epoch 172/500
# 235/235 - 0s - 2ms/step - dz: 1.2761 - kl_sindy: 0.1337 - loss: 1.4099 - reg: 0.0000e+00 - coeffs_mean: -1.6576e-01 - coeffs_scale: -5.1277e+00
# Epoch 173/500
# 235/235 - 1s - 3ms/step - dz: 1.2763 - kl_sindy: 0.1338 - loss: 1.4101 - reg: 0.0000e+00 - coeffs_mean: -1.6515e-01 - coeffs_scale: -5.1285e+00
# Epoch 174/500
# 235/235 - 0s - 2ms/step - dz: 1.2768 - kl_sindy: 0.1337 - loss: 1.4106 - reg: 0.0000e+00 - coeffs_mean: -1.6475e-01 - coeffs_scale: -5.1280e+00
# Epoch 175/500
# 235/235 - 1s - 3ms/step - dz: 1.2750 - kl_sindy: 0.1337 - loss: 1.4087 - reg: 0.0000e+00 - coeffs_mean: -1.6419e-01 - coeffs_scale: -5.1255e+00
# Epoch 176/500
# 235/235 - 1s - 3ms/step - dz: 1.2759 - kl_sindy: 0.1337 - loss: 1.4096 - reg: 0.0000e+00 - coeffs_mean: -1.6483e-01 - coeffs_scale: -5.1243e+00
# Epoch 177/500
# 235/235 - 1s - 3ms/step - dz: 1.2748 - kl_sindy: 0.1337 - loss: 1.4085 - reg: 0.0000e+00 - coeffs_mean: -1.6407e-01 - coeffs_scale: -5.1262e+00
# Epoch 178/500
# 235/235 - 1s - 3ms/step - dz: 1.2773 - kl_sindy: 0.1338 - loss: 1.4111 - reg: 0.0000e+00 - coeffs_mean: -1.6448e-01 - coeffs_scale: -5.1297e+00
# Epoch 179/500
# 235/235 - 1s - 2ms/step - dz: 1.2760 - kl_sindy: 0.1338 - loss: 1.4098 - reg: 0.0000e+00 - coeffs_mean: -1.6471e-01 - coeffs_scale: -5.1319e+00
# Epoch 180/500
# 235/235 - 1s - 2ms/step - dz: 1.2757 - kl_sindy: 0.1339 - loss: 1.4096 - reg: 0.0000e+00 - coeffs_mean: -1.6517e-01 - coeffs_scale: -5.1314e+00
# Epoch 181/500
# 235/235 - 0s - 2ms/step - dz: 1.2768 - kl_sindy: 0.1339 - loss: 1.4107 - reg: 0.0000e+00 - coeffs_mean: -1.6537e-01 - coeffs_scale: -5.1323e+00
# Epoch 182/500
# 235/235 - 0s - 2ms/step - dz: 1.2750 - kl_sindy: 0.1339 - loss: 1.4089 - reg: 0.0000e+00 - coeffs_mean: -1.6581e-01 - coeffs_scale: -5.1304e+00
# Epoch 183/500
# 235/235 - 1s - 3ms/step - dz: 1.2756 - kl_sindy: 0.1338 - loss: 1.4094 - reg: 0.0000e+00 - coeffs_mean: -1.6486e-01 - coeffs_scale: -5.1281e+00
# Epoch 184/500
# 235/235 - 1s - 3ms/step - dz: 1.2759 - kl_sindy: 0.1337 - loss: 1.4096 - reg: 0.0000e+00 - coeffs_mean: -1.6435e-01 - coeffs_scale: -5.1295e+00
# Epoch 185/500
# 235/235 - 1s - 3ms/step - dz: 1.2762 - kl_sindy: 0.1339 - loss: 1.4101 - reg: 0.0000e+00 - coeffs_mean: -1.6435e-01 - coeffs_scale: -5.1341e+00
# Epoch 186/500
# 235/235 - 0s - 1ms/step - dz: 1.2770 - kl_sindy: 0.1341 - loss: 1.4111 - reg: 0.0000e+00 - coeffs_mean: -1.6403e-01 - coeffs_scale: -5.1400e+00
# Epoch 187/500
# 235/235 - 1s - 3ms/step - dz: 1.2746 - kl_sindy: 0.1341 - loss: 1.4086 - reg: 0.0000e+00 - coeffs_mean: -1.6585e-01 - coeffs_scale: -5.1349e+00
# Epoch 188/500
# 235/235 - 0s - 1ms/step - dz: 1.2765 - kl_sindy: 0.1340 - loss: 1.4106 - reg: 0.0000e+00 - coeffs_mean: -1.6433e-01 - coeffs_scale: -5.1353e+00
# Epoch 189/500
# 235/235 - 0s - 2ms/step - dz: 1.2761 - kl_sindy: 0.1340 - loss: 1.4101 - reg: 0.0000e+00 - coeffs_mean: -1.6446e-01 - coeffs_scale: -5.1352e+00
# Epoch 190/500
# 235/235 - 0s - 2ms/step - dz: 1.2758 - kl_sindy: 0.1340 - loss: 1.4099 - reg: 0.0000e+00 - coeffs_mean: -1.6462e-01 - coeffs_scale: -5.1367e+00
# Epoch 191/500
# 235/235 - 1s - 3ms/step - dz: 1.2756 - kl_sindy: 0.1340 - loss: 1.4096 - reg: 0.0000e+00 - coeffs_mean: -1.6536e-01 - coeffs_scale: -5.1359e+00
# Epoch 192/500
# 235/235 - 0s - 2ms/step - dz: 1.2747 - kl_sindy: 0.1340 - loss: 1.4087 - reg: 0.0000e+00 - coeffs_mean: -1.6541e-01 - coeffs_scale: -5.1377e+00
# Epoch 193/500
# 235/235 - 1s - 3ms/step - dz: 1.2743 - kl_sindy: 0.1341 - loss: 1.4084 - reg: 0.0000e+00 - coeffs_mean: -1.6463e-01 - coeffs_scale: -5.1388e+00
# Epoch 194/500
# 235/235 - 1s - 3ms/step - dz: 1.2759 - kl_sindy: 0.1341 - loss: 1.4100 - reg: 0.0000e+00 - coeffs_mean: -1.6491e-01 - coeffs_scale: -5.1368e+00
# Epoch 195/500
# 235/235 - 0s - 2ms/step - dz: 1.2728 - kl_sindy: 0.1340 - loss: 1.4068 - reg: 0.0000e+00 - coeffs_mean: -1.6437e-01 - coeffs_scale: -5.1323e+00
# Epoch 196/500
# 235/235 - 0s - 2ms/step - dz: 1.2765 - kl_sindy: 0.1339 - loss: 1.4104 - reg: 0.0000e+00 - coeffs_mean: -1.6427e-01 - coeffs_scale: -5.1317e+00
# Epoch 197/500
# 235/235 - 1s - 3ms/step - dz: 1.2743 - kl_sindy: 0.1339 - loss: 1.4082 - reg: 0.0000e+00 - coeffs_mean: -1.6480e-01 - coeffs_scale: -5.1296e+00
# Epoch 198/500
# 235/235 - 1s - 3ms/step - dz: 1.2768 - kl_sindy: 0.1338 - loss: 1.4106 - reg: 0.0000e+00 - coeffs_mean: -1.6548e-01 - coeffs_scale: -5.1314e+00
# Epoch 199/500
# 235/235 - 1s - 2ms/step - dz: 1.2751 - kl_sindy: 0.1338 - loss: 1.4090 - reg: 0.0000e+00 - coeffs_mean: -1.6468e-01 - coeffs_scale: -5.1267e+00
# Epoch 200/500
# 235/235 - 1s - 4ms/step - dz: 1.2749 - kl_sindy: 0.1337 - loss: 1.4086 - reg: 0.0000e+00 - coeffs_mean: -1.6564e-01 - coeffs_scale: -5.1239e+00
# Epoch 201/500
# 235/235 - 1s - 2ms/step - dz: 1.2780 - kl_sindy: 0.1337 - loss: 1.4117 - reg: 0.0000e+00 - coeffs_mean: -1.6542e-01 - coeffs_scale: -5.1292e+00
# Epoch 202/500
# 235/235 - 1s - 3ms/step - dz: 1.2737 - kl_sindy: 0.1338 - loss: 1.4075 - reg: 0.0000e+00 - coeffs_mean: -1.6495e-01 - coeffs_scale: -5.1278e+00
# Epoch 203/500
# 235/235 - 1s - 3ms/step - dz: 1.2760 - kl_sindy: 0.1338 - loss: 1.4098 - reg: 0.0000e+00 - coeffs_mean: -1.6493e-01 - coeffs_scale: -5.1283e+00
# Epoch 204/500
# 235/235 - 1s - 4ms/step - dz: 1.2740 - kl_sindy: 0.1337 - loss: 1.4077 - reg: 0.0000e+00 - coeffs_mean: -1.6560e-01 - coeffs_scale: -5.1259e+00
# Epoch 205/500
# 235/235 - 1s - 3ms/step - dz: 1.2765 - kl_sindy: 0.1337 - loss: 1.4102 - reg: 0.0000e+00 - coeffs_mean: -1.6504e-01 - coeffs_scale: -5.1253e+00
# Epoch 206/500
# 235/235 - 0s - 1ms/step - dz: 1.2737 - kl_sindy: 0.1338 - loss: 1.4074 - reg: 0.0000e+00 - coeffs_mean: -1.6539e-01 - coeffs_scale: -5.1255e+00
# Epoch 207/500
# 235/235 - 1s - 3ms/step - dz: 1.2763 - kl_sindy: 0.1337 - loss: 1.4100 - reg: 0.0000e+00 - coeffs_mean: -1.6573e-01 - coeffs_scale: -5.1263e+00
# Epoch 208/500
# 235/235 - 1s - 3ms/step - dz: 1.2765 - kl_sindy: 0.1338 - loss: 1.4103 - reg: 0.0000e+00 - coeffs_mean: -1.6553e-01 - coeffs_scale: -5.1287e+00
# Epoch 209/500
# 235/235 - 0s - 2ms/step - dz: 1.2750 - kl_sindy: 0.1338 - loss: 1.4088 - reg: 0.0000e+00 - coeffs_mean: -1.6594e-01 - coeffs_scale: -5.1271e+00
# Epoch 210/500
# 235/235 - 1s - 3ms/step - dz: 1.2758 - kl_sindy: 0.1337 - loss: 1.4095 - reg: 0.0000e+00 - coeffs_mean: -1.6508e-01 - coeffs_scale: -5.1246e+00
# Epoch 211/500
# 235/235 - 1s - 3ms/step - dz: 1.2756 - kl_sindy: 0.1337 - loss: 1.4093 - reg: 0.0000e+00 - coeffs_mean: -1.6489e-01 - coeffs_scale: -5.1241e+00
# Epoch 212/500
# 235/235 - 1s - 3ms/step - dz: 1.2786 - kl_sindy: 0.1338 - loss: 1.4124 - reg: 0.0000e+00 - coeffs_mean: -1.6517e-01 - coeffs_scale: -5.1326e+00
# Epoch 213/500
# 235/235 - 1s - 3ms/step - dz: 1.2747 - kl_sindy: 0.1339 - loss: 1.4087 - reg: 0.0000e+00 - coeffs_mean: -1.6641e-01 - coeffs_scale: -5.1336e+00
# Epoch 214/500
# 235/235 - 1s - 4ms/step - dz: 1.2748 - kl_sindy: 0.1339 - loss: 1.4087 - reg: 0.0000e+00 - coeffs_mean: -1.6494e-01 - coeffs_scale: -5.1325e+00
# Epoch 215/500
# 235/235 - 1s - 3ms/step - dz: 1.2767 - kl_sindy: 0.1339 - loss: 1.4107 - reg: 0.0000e+00 - coeffs_mean: -1.6420e-01 - coeffs_scale: -5.1333e+00
# Epoch 216/500
# 235/235 - 0s - 2ms/step - dz: 1.2755 - kl_sindy: 0.1339 - loss: 1.4094 - reg: 0.0000e+00 - coeffs_mean: -1.6470e-01 - coeffs_scale: -5.1313e+00
# Epoch 217/500
# 235/235 - 1s - 3ms/step - dz: 1.2746 - kl_sindy: 0.1339 - loss: 1.4085 - reg: 0.0000e+00 - coeffs_mean: -1.6452e-01 - coeffs_scale: -5.1307e+00
# Epoch 218/500
# 235/235 - 1s - 3ms/step - dz: 1.2773 - kl_sindy: 0.1339 - loss: 1.4112 - reg: 0.0000e+00 - coeffs_mean: -1.6516e-01 - coeffs_scale: -5.1334e+00
# Epoch 219/500
# 235/235 - 1s - 3ms/step - dz: 1.2749 - kl_sindy: 0.1339 - loss: 1.4089 - reg: 0.0000e+00 - coeffs_mean: -1.6499e-01 - coeffs_scale: -5.1346e+00
# Epoch 220/500
# 235/235 - 0s - 2ms/step - dz: 1.2745 - kl_sindy: 0.1340 - loss: 1.4085 - reg: 0.0000e+00 - coeffs_mean: -1.6539e-01 - coeffs_scale: -5.1330e+00
# Epoch 221/500
# 235/235 - 1s - 2ms/step - dz: 1.2736 - kl_sindy: 0.1339 - loss: 1.4075 - reg: 0.0000e+00 - coeffs_mean: -1.6535e-01 - coeffs_scale: -5.1282e+00
# Epoch 222/500
# 235/235 - 1s - 3ms/step - dz: 1.2747 - kl_sindy: 0.1338 - loss: 1.4084 - reg: 0.0000e+00 - coeffs_mean: -1.6457e-01 - coeffs_scale: -5.1272e+00
# Epoch 223/500
# 235/235 - 1s - 3ms/step - dz: 1.2749 - kl_sindy: 0.1338 - loss: 1.4087 - reg: 0.0000e+00 - coeffs_mean: -1.6479e-01 - coeffs_scale: -5.1245e+00
# Epoch 224/500
# 235/235 - 1s - 3ms/step - dz: 1.2750 - kl_sindy: 0.1337 - loss: 1.4087 - reg: 0.0000e+00 - coeffs_mean: -1.6393e-01 - coeffs_scale: -5.1239e+00
# Epoch 225/500
# 235/235 - 1s - 2ms/step - dz: 1.2762 - kl_sindy: 0.1336 - loss: 1.4098 - reg: 0.0000e+00 - coeffs_mean: -1.6571e-01 - coeffs_scale: -5.1223e+00
# Epoch 226/500
# 235/235 - 1s - 2ms/step - dz: 1.2763 - kl_sindy: 0.1336 - loss: 1.4100 - reg: 0.0000e+00 - coeffs_mean: -1.6433e-01 - coeffs_scale: -5.1251e+00
# Epoch 227/500
# 235/235 - 1s - 2ms/step - dz: 1.2748 - kl_sindy: 0.1337 - loss: 1.4085 - reg: 0.0000e+00 - coeffs_mean: -1.6435e-01 - coeffs_scale: -5.1242e+00
# Epoch 228/500
# 235/235 - 1s - 3ms/step - dz: 1.2770 - kl_sindy: 0.1337 - loss: 1.4107 - reg: 0.0000e+00 - coeffs_mean: -1.6437e-01 - coeffs_scale: -5.1259e+00
# Epoch 229/500
# 235/235 - 1s - 3ms/step - dz: 1.2763 - kl_sindy: 0.1338 - loss: 1.4101 - reg: 0.0000e+00 - coeffs_mean: -1.6512e-01 - coeffs_scale: -5.1303e+00
# Epoch 230/500
# 235/235 - 1s - 5ms/step - dz: 1.2761 - kl_sindy: 0.1339 - loss: 1.4100 - reg: 0.0000e+00 - coeffs_mean: -1.6492e-01 - coeffs_scale: -5.1326e+00
# Epoch 231/500
# 235/235 - 0s - 2ms/step - dz: 1.2764 - kl_sindy: 0.1340 - loss: 1.4104 - reg: 0.0000e+00 - coeffs_mean: -1.6573e-01 - coeffs_scale: -5.1374e+00
# Epoch 232/500
# 235/235 - 1s - 3ms/step - dz: 1.2754 - kl_sindy: 0.1340 - loss: 1.4094 - reg: 0.0000e+00 - coeffs_mean: -1.6493e-01 - coeffs_scale: -5.1354e+00
# Epoch 233/500
# 235/235 - 1s - 3ms/step - dz: 1.2747 - kl_sindy: 0.1340 - loss: 1.4086 - reg: 0.0000e+00 - coeffs_mean: -1.6556e-01 - coeffs_scale: -5.1337e+00
# Epoch 234/500
# 235/235 - 1s - 3ms/step - dz: 1.2757 - kl_sindy: 0.1340 - loss: 1.4097 - reg: 0.0000e+00 - coeffs_mean: -1.6489e-01 - coeffs_scale: -5.1330e+00
# Epoch 235/500
# 235/235 - 0s - 2ms/step - dz: 1.2767 - kl_sindy: 0.1340 - loss: 1.4107 - reg: 0.0000e+00 - coeffs_mean: -1.6447e-01 - coeffs_scale: -5.1349e+00
# Epoch 236/500
# 235/235 - 0s - 1ms/step - dz: 1.2744 - kl_sindy: 0.1339 - loss: 1.4083 - reg: 0.0000e+00 - coeffs_mean: -1.6402e-01 - coeffs_scale: -5.1298e+00
# Epoch 237/500
# 235/235 - 1s - 3ms/step - dz: 1.2746 - kl_sindy: 0.1338 - loss: 1.4084 - reg: 0.0000e+00 - coeffs_mean: -1.6465e-01 - coeffs_scale: -5.1298e+00
# Epoch 238/500
# 235/235 - 0s - 1ms/step - dz: 1.2753 - kl_sindy: 0.1338 - loss: 1.4091 - reg: 0.0000e+00 - coeffs_mean: -1.6579e-01 - coeffs_scale: -5.1261e+00
# Epoch 239/500
# 235/235 - 1s - 3ms/step - dz: 1.2759 - kl_sindy: 0.1337 - loss: 1.4097 - reg: 0.0000e+00 - coeffs_mean: -1.6435e-01 - coeffs_scale: -5.1262e+00
# Epoch 240/500
# 235/235 - 0s - 1ms/step - dz: 1.2755 - kl_sindy: 0.1338 - loss: 1.4092 - reg: 0.0000e+00 - coeffs_mean: -1.6507e-01 - coeffs_scale: -5.1282e+00
# Epoch 241/500
# 235/235 - 0s - 1ms/step - dz: 1.2736 - kl_sindy: 0.1338 - loss: 1.4073 - reg: 0.0000e+00 - coeffs_mean: -1.6515e-01 - coeffs_scale: -5.1275e+00
# Epoch 242/500
# 235/235 - 0s - 2ms/step - dz: 1.2771 - kl_sindy: 0.1338 - loss: 1.4109 - reg: 0.0000e+00 - coeffs_mean: -1.6448e-01 - coeffs_scale: -5.1306e+00
# Epoch 243/500
# 235/235 - 0s - 2ms/step - dz: 1.2748 - kl_sindy: 0.1339 - loss: 1.4087 - reg: 0.0000e+00 - coeffs_mean: -1.6495e-01 - coeffs_scale: -5.1312e+00
# Epoch 244/500
# 235/235 - 1s - 3ms/step - dz: 1.2758 - kl_sindy: 0.1339 - loss: 1.4097 - reg: 0.0000e+00 - coeffs_mean: -1.6498e-01 - coeffs_scale: -5.1293e+00
# Epoch 245/500
# 235/235 - 0s - 2ms/step - dz: 1.2770 - kl_sindy: 0.1339 - loss: 1.4109 - reg: 0.0000e+00 - coeffs_mean: -1.6534e-01 - coeffs_scale: -5.1326e+00
# Epoch 246/500
# 235/235 - 1s - 2ms/step - dz: 1.2773 - kl_sindy: 0.1339 - loss: 1.4112 - reg: 0.0000e+00 - coeffs_mean: -1.6453e-01 - coeffs_scale: -5.1339e+00
# Epoch 247/500
# 235/235 - 1s - 2ms/step - dz: 1.2742 - kl_sindy: 0.1339 - loss: 1.4082 - reg: 0.0000e+00 - coeffs_mean: -1.6400e-01 - coeffs_scale: -5.1313e+00
# Epoch 248/500
# 235/235 - 1s - 3ms/step - dz: 1.2748 - kl_sindy: 0.1338 - loss: 1.4087 - reg: 0.0000e+00 - coeffs_mean: -1.6461e-01 - coeffs_scale: -5.1279e+00
# Epoch 249/500
# 235/235 - 1s - 3ms/step - dz: 1.2766 - kl_sindy: 0.1338 - loss: 1.4105 - reg: 0.0000e+00 - coeffs_mean: -1.6564e-01 - coeffs_scale: -5.1298e+00
# Epoch 250/500
# 235/235 - 1s - 2ms/step - dz: 1.2751 - kl_sindy: 0.1338 - loss: 1.4089 - reg: 0.0000e+00 - coeffs_mean: -1.6559e-01 - coeffs_scale: -5.1286e+00
# Epoch 251/500
# 235/235 - 1s - 2ms/step - dz: 1.2760 - kl_sindy: 0.1339 - loss: 1.4099 - reg: 0.0000e+00 - coeffs_mean: -1.6429e-01 - coeffs_scale: -5.1328e+00
# Epoch 252/500
# 235/235 - 0s - 2ms/step - dz: 1.2772 - kl_sindy: 0.1340 - loss: 1.4112 - reg: 0.0000e+00 - coeffs_mean: -1.6347e-01 - coeffs_scale: -5.1348e+00
# Epoch 253/500
# 235/235 - 1s - 3ms/step - dz: 1.2751 - kl_sindy: 0.1340 - loss: 1.4091 - reg: 0.0000e+00 - coeffs_mean: -1.6481e-01 - coeffs_scale: -5.1346e+00
# Epoch 254/500
# 235/235 - 1s - 3ms/step - dz: 1.2767 - kl_sindy: 0.1340 - loss: 1.4107 - reg: 0.0000e+00 - coeffs_mean: -1.6487e-01 - coeffs_scale: -5.1369e+00
# Epoch 255/500
# 235/235 - 1s - 3ms/step - dz: 1.2758 - kl_sindy: 0.1341 - loss: 1.4099 - reg: 0.0000e+00 - coeffs_mean: -1.6535e-01 - coeffs_scale: -5.1379e+00
# Epoch 256/500
# 235/235 - 1s - 3ms/step - dz: 1.2752 - kl_sindy: 0.1340 - loss: 1.4092 - reg: 0.0000e+00 - coeffs_mean: -1.6389e-01 - coeffs_scale: -5.1361e+00
# Epoch 257/500
# 235/235 - 0s - 2ms/step - dz: 1.2756 - kl_sindy: 0.1340 - loss: 1.4096 - reg: 0.0000e+00 - coeffs_mean: -1.6437e-01 - coeffs_scale: -5.1350e+00
# Epoch 258/500
# 235/235 - 1s - 3ms/step - dz: 1.2750 - kl_sindy: 0.1340 - loss: 1.4090 - reg: 0.0000e+00 - coeffs_mean: -1.6502e-01 - coeffs_scale: -5.1339e+00
# Epoch 259/500
# 235/235 - 1s - 3ms/step - dz: 1.2760 - kl_sindy: 0.1340 - loss: 1.4100 - reg: 0.0000e+00 - coeffs_mean: -1.6600e-01 - coeffs_scale: -5.1352e+00
# Epoch 260/500
# 235/235 - 1s - 3ms/step - dz: 1.2729 - kl_sindy: 0.1340 - loss: 1.4069 - reg: 0.0000e+00 - coeffs_mean: -1.6584e-01 - coeffs_scale: -5.1330e+00
# Epoch 261/500
# 235/235 - 1s - 3ms/step - dz: 1.2776 - kl_sindy: 0.1340 - loss: 1.4116 - reg: 0.0000e+00 - coeffs_mean: -1.6453e-01 - coeffs_scale: -5.1347e+00
# Epoch 262/500
# 235/235 - 0s - 2ms/step - dz: 1.2762 - kl_sindy: 0.1340 - loss: 1.4102 - reg: 0.0000e+00 - coeffs_mean: -1.6539e-01 - coeffs_scale: -5.1376e+00
# Epoch 263/500
# 235/235 - 1s - 3ms/step - dz: 1.2757 - kl_sindy: 0.1341 - loss: 1.4098 - reg: 0.0000e+00 - coeffs_mean: -1.6550e-01 - coeffs_scale: -5.1364e+00
# Epoch 264/500
# 235/235 - 0s - 1ms/step - dz: 1.2749 - kl_sindy: 0.1340 - loss: 1.4089 - reg: 0.0000e+00 - coeffs_mean: -1.6545e-01 - coeffs_scale: -5.1354e+00
# Epoch 265/500
# 235/235 - 1s - 3ms/step - dz: 1.2767 - kl_sindy: 0.1341 - loss: 1.4108 - reg: 0.0000e+00 - coeffs_mean: -1.6487e-01 - coeffs_scale: -5.1407e+00
# Epoch 266/500
# 235/235 - 0s - 2ms/step - dz: 1.2745 - kl_sindy: 0.1341 - loss: 1.4087 - reg: 0.0000e+00 - coeffs_mean: -1.6523e-01 - coeffs_scale: -5.1384e+00
# Epoch 267/500
# 235/235 - 1s - 3ms/step - dz: 1.2745 - kl_sindy: 0.1341 - loss: 1.4085 - reg: 0.0000e+00 - coeffs_mean: -1.6544e-01 - coeffs_scale: -5.1378e+00
# Epoch 268/500
# 235/235 - 0s - 1ms/step - dz: 1.2758 - kl_sindy: 0.1341 - loss: 1.4099 - reg: 0.0000e+00 - coeffs_mean: -1.6543e-01 - coeffs_scale: -5.1381e+00
# Epoch 269/500
# 235/235 - 1s - 3ms/step - dz: 1.2750 - kl_sindy: 0.1341 - loss: 1.4090 - reg: 0.0000e+00 - coeffs_mean: -1.6626e-01 - coeffs_scale: -5.1370e+00
# Epoch 270/500
# 235/235 - 1s - 3ms/step - dz: 1.2719 - kl_sindy: 0.1339 - loss: 1.4058 - reg: 0.0000e+00 - coeffs_mean: -1.6382e-01 - coeffs_scale: -5.1296e+00
# Epoch 271/500
# 235/235 - 1s - 3ms/step - dz: 1.2748 - kl_sindy: 0.1338 - loss: 1.4086 - reg: 0.0000e+00 - coeffs_mean: -1.6559e-01 - coeffs_scale: -5.1279e+00
# Epoch 272/500
# 235/235 - 1s - 3ms/step - dz: 1.2743 - kl_sindy: 0.1338 - loss: 1.4080 - reg: 0.0000e+00 - coeffs_mean: -1.6522e-01 - coeffs_scale: -5.1252e+00
# Epoch 273/500
# 235/235 - 1s - 2ms/step - dz: 1.2739 - kl_sindy: 0.1337 - loss: 1.4075 - reg: 0.0000e+00 - coeffs_mean: -1.6458e-01 - coeffs_scale: -5.1234e+00
# Epoch 274/500
# 235/235 - 1s - 3ms/step - dz: 1.2767 - kl_sindy: 0.1337 - loss: 1.4104 - reg: 0.0000e+00 - coeffs_mean: -1.6499e-01 - coeffs_scale: -5.1277e+00
# Epoch 275/500
# 235/235 - 0s - 2ms/step - dz: 1.2755 - kl_sindy: 0.1338 - loss: 1.4093 - reg: 0.0000e+00 - coeffs_mean: -1.6536e-01 - coeffs_scale: -5.1321e+00
# Epoch 276/500
# 235/235 - 1s - 3ms/step - dz: 1.2756 - kl_sindy: 0.1339 - loss: 1.4095 - reg: 0.0000e+00 - coeffs_mean: -1.6539e-01 - coeffs_scale: -5.1335e+00
# Epoch 277/500
# 235/235 - 1s - 3ms/step - dz: 1.2780 - kl_sindy: 0.1340 - loss: 1.4120 - reg: 0.0000e+00 - coeffs_mean: -1.6504e-01 - coeffs_scale: -5.1364e+00
# Epoch 278/500
# 235/235 - 0s - 1ms/step - dz: 1.2736 - kl_sindy: 0.1339 - loss: 1.4075 - reg: 0.0000e+00 - coeffs_mean: -1.6512e-01 - coeffs_scale: -5.1315e+00
# Epoch 279/500
# 235/235 - 1s - 3ms/step - dz: 1.2760 - kl_sindy: 0.1339 - loss: 1.4099 - reg: 0.0000e+00 - coeffs_mean: -1.6529e-01 - coeffs_scale: -5.1329e+00
# Epoch 280/500
# 235/235 - 1s - 3ms/step - dz: 1.2755 - kl_sindy: 0.1340 - loss: 1.4095 - reg: 0.0000e+00 - coeffs_mean: -1.6525e-01 - coeffs_scale: -5.1331e+00
# Epoch 281/500
# 235/235 - 1s - 3ms/step - dz: 1.2753 - kl_sindy: 0.1340 - loss: 1.4093 - reg: 0.0000e+00 - coeffs_mean: -1.6483e-01 - coeffs_scale: -5.1347e+00
# Epoch 282/500
# 235/235 - 1s - 3ms/step - dz: 1.2746 - kl_sindy: 0.1339 - loss: 1.4085 - reg: 0.0000e+00 - coeffs_mean: -1.6536e-01 - coeffs_scale: -5.1308e+00
# Epoch 283/500
# 235/235 - 0s - 1ms/step - dz: 1.2745 - kl_sindy: 0.1338 - loss: 1.4084 - reg: 0.0000e+00 - coeffs_mean: -1.6433e-01 - coeffs_scale: -5.1293e+00
# Epoch 284/500
# 235/235 - 1s - 3ms/step - dz: 1.2749 - kl_sindy: 0.1338 - loss: 1.4087 - reg: 0.0000e+00 - coeffs_mean: -1.6555e-01 - coeffs_scale: -5.1263e+00
# Epoch 285/500
# 235/235 - 1s - 3ms/step - dz: 1.2761 - kl_sindy: 0.1337 - loss: 1.4099 - reg: 0.0000e+00 - coeffs_mean: -1.6513e-01 - coeffs_scale: -5.1265e+00
# Epoch 286/500
# 235/235 - 0s - 2ms/step - dz: 1.2755 - kl_sindy: 0.1338 - loss: 1.4092 - reg: 0.0000e+00 - coeffs_mean: -1.6530e-01 - coeffs_scale: -5.1274e+00
# Epoch 287/500
# 235/235 - 0s - 2ms/step - dz: 1.2759 - kl_sindy: 0.1338 - loss: 1.4097 - reg: 0.0000e+00 - coeffs_mean: -1.6483e-01 - coeffs_scale: -5.1273e+00
# Epoch 288/500
# 235/235 - 0s - 1ms/step - dz: 1.2780 - kl_sindy: 0.1338 - loss: 1.4117 - reg: 0.0000e+00 - coeffs_mean: -1.6593e-01 - coeffs_scale: -5.1312e+00
# Epoch 289/500
# 235/235 - 1s - 3ms/step - dz: 1.2756 - kl_sindy: 0.1338 - loss: 1.4094 - reg: 0.0000e+00 - coeffs_mean: -1.6499e-01 - coeffs_scale: -5.1299e+00
# Epoch 290/500
# 235/235 - 0s - 1ms/step - dz: 1.2753 - kl_sindy: 0.1338 - loss: 1.4092 - reg: 0.0000e+00 - coeffs_mean: -1.6566e-01 - coeffs_scale: -5.1287e+00
# Epoch 291/500
# 235/235 - 1s - 3ms/step - dz: 1.2735 - kl_sindy: 0.1337 - loss: 1.4072 - reg: 0.0000e+00 - coeffs_mean: -1.6466e-01 - coeffs_scale: -5.1217e+00
# Epoch 292/500
# 235/235 - 1s - 3ms/step - dz: 1.2748 - kl_sindy: 0.1336 - loss: 1.4084 - reg: 0.0000e+00 - coeffs_mean: -1.6361e-01 - coeffs_scale: -5.1233e+00
# Epoch 293/500
# 235/235 - 0s - 2ms/step - dz: 1.2752 - kl_sindy: 0.1337 - loss: 1.4088 - reg: 0.0000e+00 - coeffs_mean: -1.6475e-01 - coeffs_scale: -5.1244e+00
# Epoch 294/500
# 235/235 - 1s - 4ms/step - dz: 1.2751 - kl_sindy: 0.1336 - loss: 1.4087 - reg: 0.0000e+00 - coeffs_mean: -1.6476e-01 - coeffs_scale: -5.1242e+00
# Epoch 295/500
# 235/235 - 1s - 2ms/step - dz: 1.2753 - kl_sindy: 0.1337 - loss: 1.4090 - reg: 0.0000e+00 - coeffs_mean: -1.6587e-01 - coeffs_scale: -5.1207e+00
# Epoch 296/500
# 235/235 - 1s - 3ms/step - dz: 1.2756 - kl_sindy: 0.1336 - loss: 1.4092 - reg: 0.0000e+00 - coeffs_mean: -1.6451e-01 - coeffs_scale: -5.1218e+00
# Epoch 297/500
# 235/235 - 1s - 2ms/step - dz: 1.2754 - kl_sindy: 0.1336 - loss: 1.4090 - reg: 0.0000e+00 - coeffs_mean: -1.6558e-01 - coeffs_scale: -5.1230e+00
# Epoch 298/500
# 235/235 - 1s - 2ms/step - dz: 1.2759 - kl_sindy: 0.1337 - loss: 1.4096 - reg: 0.0000e+00 - coeffs_mean: -1.6700e-01 - coeffs_scale: -5.1232e+00
# Epoch 299/500
# 235/235 - 0s - 2ms/step - dz: 1.2764 - kl_sindy: 0.1336 - loss: 1.4100 - reg: 0.0000e+00 - coeffs_mean: -1.6575e-01 - coeffs_scale: -5.1232e+00
# Epoch 300/500
# 235/235 - 0s - 2ms/step - dz: 1.2772 - kl_sindy: 0.1337 - loss: 1.4108 - reg: 0.0000e+00 - coeffs_mean: -1.6452e-01 - coeffs_scale: -5.1243e+00
# Epoch 301/500
# 235/235 - 0s - 1ms/step - dz: 1.2772 - kl_sindy: 0.1338 - loss: 1.4110 - reg: 0.0000e+00 - coeffs_mean: -1.6601e-01 - coeffs_scale: -5.1316e+00
# Epoch 302/500
# 235/235 - 0s - 2ms/step - dz: 1.2747 - kl_sindy: 0.1339 - loss: 1.4087 - reg: 0.0000e+00 - coeffs_mean: -1.6518e-01 - coeffs_scale: -5.1295e+00
# Epoch 303/500
# 235/235 - 1s - 3ms/step - dz: 1.2767 - kl_sindy: 0.1339 - loss: 1.4106 - reg: 0.0000e+00 - coeffs_mean: -1.6494e-01 - coeffs_scale: -5.1313e+00
# Epoch 304/500
# 235/235 - 1s - 3ms/step - dz: 1.2742 - kl_sindy: 0.1339 - loss: 1.4081 - reg: 0.0000e+00 - coeffs_mean: -1.6465e-01 - coeffs_scale: -5.1271e+00
# Epoch 305/500
# ...
# Epoch 406/500
# 235/235 - 1s - 3ms/step - dz: 1.2755 - kl_sindy: 0.1338 - loss: 1.4093 - reg: 0.0000e+00 - coeffs_mean: -1.6481e-01 - coeffs_scale: -5.1261e+00
# Epoch 407/500
# 235/235 - 0s - 2ms/step - dz: 1.2741 - kl_sindy: 0.1337 - loss: 1.4078 - reg: 0.0000e+00 - coeffs_mean: -1.6570e-01 - coeffs_scale: -5.1249e+00
# Epoch 408/500
# 235/235 - 1s - 3ms/step - dz: 1.2768 - kl_sindy: 0.1337 - loss: 1.4105 - reg: 0.0000e+00 - coeffs_mean: -1.6487e-01 - coeffs_scale: -5.1278e+00
# Epoch 409/500
# 235/235 - 1s - 3ms/step - dz: 1.2755 - kl_sindy: 0.1338 - loss: 1.4093 - reg: 0.0000e+00 - coeffs_mean: -1.6462e-01 - coeffs_scale: -5.1277e+00
# Epoch 410/500
# 235/235 - 1s - 3ms/step - dz: 1.2750 - kl_sindy: 0.1338 - loss: 1.4088 - reg: 0.0000e+00 - coeffs_mean: -1.6594e-01 - coeffs_scale: -5.1303e+00
# Epoch 411/500
# 235/235 - 1s - 3ms/step - dz: 1.2745 - kl_sindy: 0.1338 - loss: 1.4083 - reg: 0.0000e+00 - coeffs_mean: -1.6510e-01 - coeffs_scale: -5.1272e+00
# Epoch 412/500
# 235/235 - 1s - 3ms/step - dz: 1.2747 - kl_sindy: 0.1338 - loss: 1.4084 - reg: 0.0000e+00 - coeffs_mean: -1.6576e-01 - coeffs_scale: -5.1253e+00
# Epoch 413/500
# 235/235 - 1s - 3ms/step - dz: 1.2752 - kl_sindy: 0.1337 - loss: 1.4089 - reg: 0.0000e+00 - coeffs_mean: -1.6573e-01 - coeffs_scale: -5.1270e+00
# Epoch 414/500
# 235/235 - 1s - 2ms/step - dz: 1.2737 - kl_sindy: 0.1337 - loss: 1.4074 - reg: 0.0000e+00 - coeffs_mean: -1.6551e-01 - coeffs_scale: -5.1241e+00
# Epoch 415/500
# 235/235 - 1s - 3ms/step - dz: 1.2743 - kl_sindy: 0.1337 - loss: 1.4080 - reg: 0.0000e+00 - coeffs_mean: -1.6450e-01 - coeffs_scale: -5.1247e+00
# Epoch 416/500
# 235/235 - 0s - 2ms/step - dz: 1.2758 - kl_sindy: 0.1338 - loss: 1.4096 - reg: 0.0000e+00 - coeffs_mean: -1.6557e-01 - coeffs_scale: -5.1299e+00
# Epoch 417/500
# 235/235 - 1s - 2ms/step - dz: 1.2765 - kl_sindy: 0.1339 - loss: 1.4103 - reg: 0.0000e+00 - coeffs_mean: -1.6458e-01 - coeffs_scale: -5.1305e+00
# Epoch 418/500
# 235/235 - 1s - 3ms/step - dz: 1.2752 - kl_sindy: 0.1339 - loss: 1.4090 - reg: 0.0000e+00 - coeffs_mean: -1.6520e-01 - coeffs_scale: -5.1295e+00
# Epoch 419/500
# 235/235 - 1s - 3ms/step - dz: 1.2753 - kl_sindy: 0.1338 - loss: 1.4091 - reg: 0.0000e+00 - coeffs_mean: -1.6427e-01 - coeffs_scale: -5.1281e+00
# Epoch 420/500
# 235/235 - 1s - 3ms/step - dz: 1.2741 - kl_sindy: 0.1338 - loss: 1.4079 - reg: 0.0000e+00 - coeffs_mean: -1.6491e-01 - coeffs_scale: -5.1267e+00
# Epoch 421/500
# 235/235 - 0s - 2ms/step - dz: 1.2769 - kl_sindy: 0.1338 - loss: 1.4107 - reg: 0.0000e+00 - coeffs_mean: -1.6538e-01 - coeffs_scale: -5.1283e+00
# Epoch 422/500
# 235/235 - 1s - 3ms/step - dz: 1.2764 - kl_sindy: 0.1339 - loss: 1.4103 - reg: 0.0000e+00 - coeffs_mean: -1.6601e-01 - coeffs_scale: -5.1306e+00
# Epoch 423/500
# 235/235 - 1s - 3ms/step - dz: 1.2747 - kl_sindy: 0.1339 - loss: 1.4086 - reg: 0.0000e+00 - coeffs_mean: -1.6631e-01 - coeffs_scale: -5.1303e+00
# Epoch 424/500
# 235/235 - 1s - 3ms/step - dz: 1.2762 - kl_sindy: 0.1338 - loss: 1.4101 - reg: 0.0000e+00 - coeffs_mean: -1.6492e-01 - coeffs_scale: -5.1290e+00
# Epoch 425/500
# 235/235 - 1s - 3ms/step - dz: 1.2763 - kl_sindy: 0.1338 - loss: 1.4102 - reg: 0.0000e+00 - coeffs_mean: -1.6506e-01 - coeffs_scale: -5.1311e+00
# Epoch 426/500
# 235/235 - 1s - 3ms/step - dz: 1.2757 - kl_sindy: 0.1339 - loss: 1.4097 - reg: 0.0000e+00 - coeffs_mean: -1.6529e-01 - coeffs_scale: -5.1328e+00
# Epoch 427/500
# 235/235 - 1s - 3ms/step - dz: 1.2773 - kl_sindy: 0.1340 - loss: 1.4113 - reg: 0.0000e+00 - coeffs_mean: -1.6483e-01 - coeffs_scale: -5.1355e+00
# Epoch 428/500
# 235/235 - 0s - 2ms/step - dz: 1.2755 - kl_sindy: 0.1340 - loss: 1.4095 - reg: 0.0000e+00 - coeffs_mean: -1.6543e-01 - coeffs_scale: -5.1352e+00
# Epoch 429/500
# 235/235 - 1s - 3ms/step - dz: 1.2759 - kl_sindy: 0.1340 - loss: 1.4100 - reg: 0.0000e+00 - coeffs_mean: -1.6530e-01 - coeffs_scale: -5.1330e+00
# Epoch 430/500
# 235/235 - 0s - 2ms/step - dz: 1.2746 - kl_sindy: 0.1339 - loss: 1.4085 - reg: 0.0000e+00 - coeffs_mean: -1.6524e-01 - coeffs_scale: -5.1307e+00
# Epoch 431/500
# 235/235 - 0s - 2ms/step - dz: 1.2770 - kl_sindy: 0.1339 - loss: 1.4109 - reg: 0.0000e+00 - coeffs_mean: -1.6542e-01 - coeffs_scale: -5.1331e+00
# Epoch 432/500
# 235/235 - 0s - 2ms/step - dz: 1.2767 - kl_sindy: 0.1340 - loss: 1.4107 - reg: 0.0000e+00 - coeffs_mean: -1.6540e-01 - coeffs_scale: -5.1326e+00
# Epoch 433/500
# 235/235 - 0s - 2ms/step - dz: 1.2769 - kl_sindy: 0.1340 - loss: 1.4109 - reg: 0.0000e+00 - coeffs_mean: -1.6545e-01 - coeffs_scale: -5.1378e+00
# Epoch 434/500
# 235/235 - 0s - 1ms/step - dz: 1.2743 - kl_sindy: 0.1340 - loss: 1.4084 - reg: 0.0000e+00 - coeffs_mean: -1.6500e-01 - coeffs_scale: -5.1364e+00
# Epoch 435/500
# 235/235 - 0s - 2ms/step - dz: 1.2756 - kl_sindy: 0.1341 - loss: 1.4097 - reg: 0.0000e+00 - coeffs_mean: -1.6500e-01 - coeffs_scale: -5.1377e+00
# Epoch 436/500
# 235/235 - 1s - 3ms/step - dz: 1.2738 - kl_sindy: 0.1340 - loss: 1.4079 - reg: 0.0000e+00 - coeffs_mean: -1.6510e-01 - coeffs_scale: -5.1350e+00
# Epoch 437/500
# 235/235 - 1s - 2ms/step - dz: 1.2773 - kl_sindy: 0.1340 - loss: 1.4114 - reg: 0.0000e+00 - coeffs_mean: -1.6599e-01 - coeffs_scale: -5.1364e+00
# Epoch 438/500
# 235/235 - 1s - 3ms/step - dz: 1.2746 - kl_sindy: 0.1340 - loss: 1.4087 - reg: 0.0000e+00 - coeffs_mean: -1.6534e-01 - coeffs_scale: -5.1404e+00
# Epoch 439/500
# 235/235 - 1s - 2ms/step - dz: 1.2780 - kl_sindy: 0.1342 - loss: 1.4122 - reg: 0.0000e+00 - coeffs_mean: -1.6465e-01 - coeffs_scale: -5.1433e+00
# Epoch 440/500
# 235/235 - 1s - 2ms/step - dz: 1.2762 - kl_sindy: 0.1343 - loss: 1.4105 - reg: 0.0000e+00 - coeffs_mean: -1.6501e-01 - coeffs_scale: -5.1445e+00
# Epoch 441/500
# 235/235 - 1s - 2ms/step - dz: 1.2737 - kl_sindy: 0.1342 - loss: 1.4079 - reg: 0.0000e+00 - coeffs_mean: -1.6560e-01 - coeffs_scale: -5.1402e+00
# Epoch 442/500
# 235/235 - 0s - 2ms/step - dz: 1.2754 - kl_sindy: 0.1341 - loss: 1.4095 - reg: 0.0000e+00 - coeffs_mean: -1.6492e-01 - coeffs_scale: -5.1387e+00
# Epoch 443/500
# 235/235 - 0s - 1ms/step - dz: 1.2757 - kl_sindy: 0.1341 - loss: 1.4097 - reg: 0.0000e+00 - coeffs_mean: -1.6396e-01 - coeffs_scale: -5.1363e+00
# Epoch 444/500
# 235/235 - 1s - 3ms/step - dz: 1.2746 - kl_sindy: 0.1340 - loss: 1.4086 - reg: 0.0000e+00 - coeffs_mean: -1.6513e-01 - coeffs_scale: -5.1361e+00
# Epoch 445/500
# 235/235 - 1s - 3ms/step - dz: 1.2749 - kl_sindy: 0.1340 - loss: 1.4089 - reg: 0.0000e+00 - coeffs_mean: -1.6419e-01 - coeffs_scale: -5.1348e+00
# Epoch 446/500
# 235/235 - 0s - 1ms/step - dz: 1.2765 - kl_sindy: 0.1340 - loss: 1.4105 - reg: 0.0000e+00 - coeffs_mean: -1.6545e-01 - coeffs_scale: -5.1359e+00
# Epoch 447/500
# 235/235 - 1s - 3ms/step - dz: 1.2746 - kl_sindy: 0.1340 - loss: 1.4086 - reg: 0.0000e+00 - coeffs_mean: -1.6564e-01 - coeffs_scale: -5.1338e+00
# Epoch 448/500
# 235/235 - 0s - 2ms/step - dz: 1.2747 - kl_sindy: 0.1339 - loss: 1.4086 - reg: 0.0000e+00 - coeffs_mean: -1.6630e-01 - coeffs_scale: -5.1317e+00
# Epoch 449/500
# 235/235 - 0s - 2ms/step - dz: 1.2756 - kl_sindy: 0.1339 - loss: 1.4094 - reg: 0.0000e+00 - coeffs_mean: -1.6545e-01 - coeffs_scale: -5.1299e+00
# Epoch 450/500
# 235/235 - 0s - 2ms/step - dz: 1.2744 - kl_sindy: 0.1338 - loss: 1.4082 - reg: 0.0000e+00 - coeffs_mean: -1.6535e-01 - coeffs_scale: -5.1283e+00
# Epoch 451/500
# 235/235 - 0s - 2ms/step - dz: 1.2753 - kl_sindy: 0.1338 - loss: 1.4091 - reg: 0.0000e+00 - coeffs_mean: -1.6529e-01 - coeffs_scale: -5.1263e+00
# Epoch 452/500
# 235/235 - 1s - 3ms/step - dz: 1.2753 - kl_sindy: 0.1337 - loss: 1.4090 - reg: 0.0000e+00 - coeffs_mean: -1.6460e-01 - coeffs_scale: -5.1240e+00
# Epoch 453/500
# 235/235 - 1s - 3ms/step - dz: 1.2758 - kl_sindy: 0.1337 - loss: 1.4094 - reg: 0.0000e+00 - coeffs_mean: -1.6452e-01 - coeffs_scale: -5.1264e+00
# Epoch 454/500
# 235/235 - 1s - 2ms/step - dz: 1.2745 - kl_sindy: 0.1337 - loss: 1.4082 - reg: 0.0000e+00 - coeffs_mean: -1.6512e-01 - coeffs_scale: -5.1265e+00
# Epoch 455/500
# 235/235 - 1s - 3ms/step - dz: 1.2754 - kl_sindy: 0.1337 - loss: 1.4092 - reg: 0.0000e+00 - coeffs_mean: -1.6496e-01 - coeffs_scale: -5.1283e+00
# Epoch 456/500
# 235/235 - 1s - 3ms/step - dz: 1.2729 - kl_sindy: 0.1337 - loss: 1.4067 - reg: 0.0000e+00 - coeffs_mean: -1.6530e-01 - coeffs_scale: -5.1239e+00
# Epoch 457/500
# 235/235 - 0s - 1ms/step - dz: 1.2755 - kl_sindy: 0.1337 - loss: 1.4092 - reg: 0.0000e+00 - coeffs_mean: -1.6431e-01 - coeffs_scale: -5.1262e+00
# Epoch 458/500
# 235/235 - 1s - 3ms/step - dz: 1.2755 - kl_sindy: 0.1337 - loss: 1.4093 - reg: 0.0000e+00 - coeffs_mean: -1.6495e-01 - coeffs_scale: -5.1265e+00
# Epoch 459/500
# 235/235 - 1s - 3ms/step - dz: 1.2750 - kl_sindy: 0.1338 - loss: 1.4088 - reg: 0.0000e+00 - coeffs_mean: -1.6451e-01 - coeffs_scale: -5.1286e+00
# Epoch 460/500
# 235/235 - 0s - 2ms/step - dz: 1.2747 - kl_sindy: 0.1337 - loss: 1.4085 - reg: 0.0000e+00 - coeffs_mean: -1.6532e-01 - coeffs_scale: -5.1250e+00
# Epoch 461/500
# 235/235 - 1s - 3ms/step - dz: 1.2737 - kl_sindy: 0.1337 - loss: 1.4074 - reg: 0.0000e+00 - coeffs_mean: -1.6559e-01 - coeffs_scale: -5.1249e+00
# Epoch 462/500
# 235/235 - 1s - 2ms/step - dz: 1.2759 - kl_sindy: 0.1336 - loss: 1.4095 - reg: 0.0000e+00 - coeffs_mean: -1.6529e-01 - coeffs_scale: -5.1227e+00
# Epoch 463/500
# 235/235 - 1s - 2ms/step - dz: 1.2766 - kl_sindy: 0.1337 - loss: 1.4103 - reg: 0.0000e+00 - coeffs_mean: -1.6521e-01 - coeffs_scale: -5.1236e+00
# Epoch 464/500
# 235/235 - 1s - 2ms/step - dz: 1.2765 - kl_sindy: 0.1337 - loss: 1.4102 - reg: 0.0000e+00 - coeffs_mean: -1.6502e-01 - coeffs_scale: -5.1281e+00
# Epoch 465/500
# 235/235 - 0s - 2ms/step - dz: 1.2746 - kl_sindy: 0.1337 - loss: 1.4083 - reg: 0.0000e+00 - coeffs_mean: -1.6432e-01 - coeffs_scale: -5.1247e+00
# Epoch 466/500
# 235/235 - 1s - 3ms/step - dz: 1.2770 - kl_sindy: 0.1337 - loss: 1.4107 - reg: 0.0000e+00 - coeffs_mean: -1.6657e-01 - coeffs_scale: -5.1274e+00
# Epoch 467/500
# 235/235 - 0s - 2ms/step - dz: 1.2778 - kl_sindy: 0.1338 - loss: 1.4116 - reg: 0.0000e+00 - coeffs_mean: -1.6424e-01 - coeffs_scale: -5.1318e+00
# Epoch 468/500
# 235/235 - 1s - 3ms/step - dz: 1.2768 - kl_sindy: 0.1340 - loss: 1.4107 - reg: 0.0000e+00 - coeffs_mean: -1.6557e-01 - coeffs_scale: -5.1366e+00
# Epoch 469/500
# 235/235 - 1s - 3ms/step - dz: 1.2722 - kl_sindy: 0.1339 - loss: 1.4061 - reg: 0.0000e+00 - coeffs_mean: -1.6404e-01 - coeffs_scale: -5.1302e+00
# Epoch 470/500
# 235/235 - 0s - 1ms/step - dz: 1.2754 - kl_sindy: 0.1338 - loss: 1.4092 - reg: 0.0000e+00 - coeffs_mean: -1.6485e-01 - coeffs_scale: -5.1304e+00
# Epoch 471/500
# 235/235 - 1s - 3ms/step - dz: 1.2736 - kl_sindy: 0.1338 - loss: 1.4074 - reg: 0.0000e+00 - coeffs_mean: -1.6496e-01 - coeffs_scale: -5.1286e+00
# Epoch 472/500
# 235/235 - 1s - 3ms/step - dz: 1.2737 - kl_sindy: 0.1338 - loss: 1.4075 - reg: 0.0000e+00 - coeffs_mean: -1.6480e-01 - coeffs_scale: -5.1266e+00
# Epoch 473/500
# 235/235 - 0s - 2ms/step - dz: 1.2755 - kl_sindy: 0.1337 - loss: 1.4092 - reg: 0.0000e+00 - coeffs_mean: -1.6494e-01 - coeffs_scale: -5.1247e+00
# Epoch 474/500
# 235/235 - 1s - 3ms/step - dz: 1.2741 - kl_sindy: 0.1337 - loss: 1.4079 - reg: 0.0000e+00 - coeffs_mean: -1.6508e-01 - coeffs_scale: -5.1249e+00
# Epoch 475/500
# 235/235 - 0s - 2ms/step - dz: 1.2741 - kl_sindy: 0.1336 - loss: 1.4077 - reg: 0.0000e+00 - coeffs_mean: -1.6527e-01 - coeffs_scale: -5.1204e+00
# Epoch 476/500
# 235/235 - 1s - 3ms/step - dz: 1.2758 - kl_sindy: 0.1336 - loss: 1.4094 - reg: 0.0000e+00 - coeffs_mean: -1.6545e-01 - coeffs_scale: -5.1254e+00
# Epoch 477/500
# 235/235 - 1s - 3ms/step - dz: 1.2754 - kl_sindy: 0.1337 - loss: 1.4091 - reg: 0.0000e+00 - coeffs_mean: -1.6518e-01 - coeffs_scale: -5.1252e+00
# Epoch 478/500
# 235/235 - 1s - 2ms/step - dz: 1.2763 - kl_sindy: 0.1337 - loss: 1.4100 - reg: 0.0000e+00 - coeffs_mean: -1.6484e-01 - coeffs_scale: -5.1254e+00
# Epoch 479/500
# 235/235 - 0s - 2ms/step - dz: 1.2744 - kl_sindy: 0.1337 - loss: 1.4081 - reg: 0.0000e+00 - coeffs_mean: -1.6422e-01 - coeffs_scale: -5.1223e+00
# Epoch 480/500
# 235/235 - 1s - 3ms/step - dz: 1.2771 - kl_sindy: 0.1336 - loss: 1.4107 - reg: 0.0000e+00 - coeffs_mean: -1.6477e-01 - coeffs_scale: -5.1250e+00
# Epoch 481/500
# 235/235 - 1s - 2ms/step - dz: 1.2765 - kl_sindy: 0.1338 - loss: 1.4103 - reg: 0.0000e+00 - coeffs_mean: -1.6496e-01 - coeffs_scale: -5.1291e+00
# Epoch 482/500
# 235/235 - 0s - 2ms/step - dz: 1.2754 - kl_sindy: 0.1338 - loss: 1.4092 - reg: 0.0000e+00 - coeffs_mean: -1.6481e-01 - coeffs_scale: -5.1315e+00
# Epoch 483/500
# 235/235 - 1s - 2ms/step - dz: 1.2751 - kl_sindy: 0.1339 - loss: 1.4090 - reg: 0.0000e+00 - coeffs_mean: -1.6429e-01 - coeffs_scale: -5.1327e+00
# Epoch 484/500
# 235/235 - 1s - 3ms/step - dz: 1.2769 - kl_sindy: 0.1339 - loss: 1.4108 - reg: 0.0000e+00 - coeffs_mean: -1.6503e-01 - coeffs_scale: -5.1348e+00
# Epoch 485/500
# 235/235 - 1s - 4ms/step - dz: 1.2733 - kl_sindy: 0.1339 - loss: 1.4072 - reg: 0.0000e+00 - coeffs_mean: -1.6505e-01 - coeffs_scale: -5.1311e+00
# Epoch 486/500
# 235/235 - 1s - 2ms/step - dz: 1.2775 - kl_sindy: 0.1339 - loss: 1.4113 - reg: 0.0000e+00 - coeffs_mean: -1.6488e-01 - coeffs_scale: -5.1333e+00
# Epoch 487/500
# 235/235 - 1s - 3ms/step - dz: 1.2746 - kl_sindy: 0.1340 - loss: 1.4086 - reg: 0.0000e+00 - coeffs_mean: -1.6475e-01 - coeffs_scale: -5.1364e+00
# Epoch 488/500
# 235/235 - 1s - 3ms/step - dz: 1.2757 - kl_sindy: 0.1341 - loss: 1.4097 - reg: 0.0000e+00 - coeffs_mean: -1.6435e-01 - coeffs_scale: -5.1367e+00
# Epoch 489/500
# 235/235 - 1s - 3ms/step - dz: 1.2764 - kl_sindy: 0.1340 - loss: 1.4105 - reg: 0.0000e+00 - coeffs_mean: -1.6517e-01 - coeffs_scale: -5.1397e+00
# Epoch 490/500
# 235/235 - 0s - 2ms/step - dz: 1.2738 - kl_sindy: 0.1341 - loss: 1.4079 - reg: 0.0000e+00 - coeffs_mean: -1.6557e-01 - coeffs_scale: -5.1355e+00
# Epoch 491/500
# 235/235 - 0s - 2ms/step - dz: 1.2755 - kl_sindy: 0.1340 - loss: 1.4094 - reg: 0.0000e+00 - coeffs_mean: -1.6515e-01 - coeffs_scale: -5.1344e+00
# Epoch 492/500
# 235/235 - 1s - 3ms/step - dz: 1.2760 - kl_sindy: 0.1340 - loss: 1.4100 - reg: 0.0000e+00 - coeffs_mean: -1.6499e-01 - coeffs_scale: -5.1372e+00
# Epoch 493/500
# 235/235 - 1s - 3ms/step - dz: 1.2744 - kl_sindy: 0.1341 - loss: 1.4085 - reg: 0.0000e+00 - coeffs_mean: -1.6310e-01 - coeffs_scale: -5.1371e+00
# Epoch 494/500
# 235/235 - 0s - 2ms/step - dz: 1.2744 - kl_sindy: 0.1340 - loss: 1.4084 - reg: 0.0000e+00 - coeffs_mean: -1.6398e-01 - coeffs_scale: -5.1332e+00
# Epoch 495/500
# 235/235 - 1s - 3ms/step - dz: 1.2743 - kl_sindy: 0.1339 - loss: 1.4082 - reg: 0.0000e+00 - coeffs_mean: -1.6541e-01 - coeffs_scale: -5.1319e+00
# Epoch 496/500
# 235/235 - 0s - 2ms/step - dz: 1.2769 - kl_sindy: 0.1339 - loss: 1.4108 - reg: 0.0000e+00 - coeffs_mean: -1.6478e-01 - coeffs_scale: -5.1350e+00
# Epoch 497/500
# 235/235 - 0s - 2ms/step - dz: 1.2761 - kl_sindy: 0.1340 - loss: 1.4102 - reg: 0.0000e+00 - coeffs_mean: -1.6404e-01 - coeffs_scale: -5.1361e+00
# Epoch 498/500
# 235/235 - 0s - 2ms/step - dz: 1.2757 - kl_sindy: 0.1340 - loss: 1.4097 - reg: 0.0000e+00 - coeffs_mean: -1.6450e-01 - coeffs_scale: -5.1349e+00
# Epoch 499/500
# 235/235 - 1s - 3ms/step - dz: 1.2786 - kl_sindy: 0.1341 - loss: 1.4127 - reg: 0.0000e+00 - coeffs_mean: -1.6474e-01 - coeffs_scale: -5.1388e+00
# Epoch 500/500
# 235/235 - 0s - 1ms/step - dz: 1.2745 - kl_sindy: 0.1341 - loss: 1.4085 - reg: 0.0000e+00 - coeffs_mean: -1.6514e-01 - coeffs_scale: -5.1363e+00
# INFO:root:Canceling coefficient 1
# INFO:root:Canceling coefficient z_0
# INFO:root:Canceling coefficient z_0^2
# INFO:root:Canceling coefficient z_0*z_1
# INFO:root:Canceling coefficient z_0*z_2
# INFO:root:Canceling coefficient z_1^2
# INFO:root:Canceling coefficient z_1*z_2
# INFO:root:Canceling coefficient z_2^2
# INFO:root:Canceling coefficient 1
# INFO:root:Canceling coefficient z_2
# INFO:root:Canceling coefficient z_0^2
# INFO:root:Canceling coefficient z_0*z_1
# INFO:root:Canceling coefficient z_0*z_2
# INFO:root:Canceling coefficient z_1^2
# INFO:root:Canceling coefficient z_1*z_2
# INFO:root:Canceling coefficient z_2^2
# INFO:root:Canceling coefficient z_0
# INFO:root:Canceling coefficient z_1
# INFO:root:Canceling coefficient z_0^2
# INFO:root:Canceling coefficient z_0*z_1
# INFO:root:Canceling coefficient z_1^2
# INFO:root:Canceling coefficient z_1*z_2
# dz0 = - 0.995*z1 - 0.992*z2
# dz1 = + 1.001*z0 + 0.205*z1
# dz2 = + 0.221*1 - 5.288*z2 + 0.973*z0*z2 - 0.014*z2^2

# %% [markdown]
# Let's plot the training history of the VINDy model and check how the coefficients evolved during training.
# We plot the coefficients of the VINDy model to see which terms are learned by the model.

# %%
# plot training history
training_plot(sindy_layer, trainhist, var_names)

# %% [markdown]
# We can now use the trained VINDy model to predict the future states of the Roessler system. We will use the scipy.integrate.solve_ivp function to integrate the ODEs using the predicted time derivatives.

# %%
# %% integration
nt = t.shape[0]
i_test = 0
# integrate the model
t_0 = i_test * int(nt)
sol = model.integrate(x_test[t_0 : t_0 + 1].squeeze(), t.squeeze(), mu=None)
t_pred = sol.t
x_pred = sol.y

trajectory_plot(t, x_test, t_pred, x_pred, dim, nt, i_test, var_names)

# %% [markdown]
# ## Uncertainty quantification
# Instead of only using the mean coefficients for a single prediction, we can also sample various models and use them to predict the future states of the Roessler system. This will give us an idea of the uncertainty in the model predictions.
# Forward UQ:
# * We sample SINDy coefficients from the predicted posterior distribution
# * We integrate the ODE with the sampled coefficients and collect the trajectories

# %%
n_traj = 10
# Store the original coefficients
kernel_orig, kernel_scale_orig = sindy_layer.kernel, sindy_layer.kernel_scale

t_preds = []
x_preds = []
t_0 = i_test * int(nt)
print(f"test trajectory {i_test}")
# List to store the solution trajectories in latent space
for traj in range(n_traj):
    print(f"\t sample {traj+1} out of {n_traj}")
    # Sample from the posterior distribution of the coefficients
    sampled_coeff, f_, ff_ = sindy_layer._coeffs
    # only take non-zero coefficients
    sampled_coeff = sampled_coeff.numpy()
    sampled_coeff = sampled_coeff[sampled_coeff != 0]

    # Assign the sampled coefficients to the SINDy layer
    sindy_layer.kernel = tf.reshape(sampled_coeff, (-1, 1))
    sol = model.integrate(x_test[t_0:t_0 + 1].squeeze(),
                          t.squeeze())
    t_preds.append(sol.t)
    x_preds.append(sol.y)
# restore original coefficients
sindy_layer.kernel, sindy_layer.kernel_scale = kernel_orig, kernel_scale_orig
# calculate mean and variance of the trajectories
x_uq = np.array(x_preds)
x_uq_mean_sampled = np.mean(x_uq, axis=0)
x_uq_std = np.std(x_uq, axis=0)
# UQ plot
uq_plot(t, x_test, t_preds, x_pred, x_uq_mean_sampled, x_uq_std, dim, nt, i_test)
# Out:
# test trajectory 0
# 	 sample 1 out of 10
# 	 sample 2 out of 10
# 	 sample 3 out of 10
# 	 sample 4 out of 10
# 	 sample 5 out of 10
# 	 sample 6 out of 10
# 	 sample 7 out of 10
# 	 sample 8 out of 10
# 	 sample 9 out of 10
# 	 sample 10 out of 10
